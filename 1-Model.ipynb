# %%
"""
Model Architecture + Baseline Loss
=============================================================

What you have:
- A clean model class that predicts 5 parameters: (cx, cy, l1, l2, l3).
- A simple baseline regression loss (SmoothL1 by default).

Expected I/O (very important):
- Input: 20×20 Grayscale image tensor, shape (N, 1, 20, 20).
- Output: tensor of shape (N, 5) = [cx, cy, l1, l2, l3].
- Target convention: l1 = Σ00, l2 = Σ11, l3 = Σ01 from the 2×2 covariance matrix.
- Normalization: **Targets for l1, l2, l3 should be divided by 400** before loss/training, so that all outputs are ~O(1).

Tasks:
1) Implement the Dataset + DataLoader to read images and JSON annotations.
2) Compute dataset mean/std and apply torchvision Normalize with those real stats.
3) Write the training/validation/test loops and metrics.
4) Implement Quantization-Aware Training (QAT): module fusion, observers, prepare_qat → train → convert.
5) Add evaluation plots and an ablation plan (baseline FP32 vs QAT variants).

Notes:
- This file intentionally omits logging, schedulers, early stopping, and custom constraints.
- You may widen/deepen the model, but keep the 5-output head.
"""
# Out:
# '\nModel Architecture + Baseline Loss\n=============================================================\n\nWhat you have:\n- A clean model class that predicts 5 parameters: (cx, cy, l1, l2, l3).\n- A simple baseline regression loss (SmoothL1 by default).\n\nExpected I/O (very important):\n- Input: 20×20 Grayscale image tensor, shape (N, 1, 20, 20).\n- Output: tensor of shape (N, 5) = [cx, cy, l1, l2, l3].\n- Target convention: l1 = Σ00, l2 = Σ11, l3 = Σ01 from the 2×2 covariance matrix.\n- Normalization: **Targets for l1, l2, l3 should be divided by 400** before loss/training, so that all outputs are ~O(1).\n\nTasks:\n1) Implement the Dataset + DataLoader to read images and JSON annotations.\n2) Compute dataset mean/std and apply torchvision Normalize with those real stats.\n3) Write the training/validation/test loops and metrics.\n4) Implement Quantization-Aware Training (QAT): module fusion, observers, prepare_qat → train → convert.\n5) Add evaluation plots and an ablation plan (baseline FP32 vs QAT variants).\n\nNotes:\n- This file intentionally omits logging, schedulers, early stopping, and custom constraints.\n- You may widen/deepen the model, but keep the 5-output head.\n'

# %%
from __future__ import annotations
import torch
import torch.nn as nn

# %%
import brevitas.nn as qnn
import brevitas.quant as quant
import torch.nn as nn

# %%
class EllipseRegressionModel(nn.Module):
    """Small CNN for regressing (cx, cy, l1, l2, l3) from 20×20 RGB.

    Design:
      - 4× (Conv → BN → LeakyReLU → MaxPool2d(2))
      - Flatten → 2× Linear → 5-dim output

    With 20×20 input, four 2× pools map features to 1×1.
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2)
        self.act = nn.LeakyReLU(negative_slope=0.01, inplace=True)

        self.fc1 = nn.Linear(256 * 1 * 1, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc_out = nn.Linear(256, 5)  # (cx, cy, l1, l2, l3) — l* expected normalized by /400 in targets

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(self.act(self.bn1(self.conv1(x))))  # 20→10
        x = self.pool(self.act(self.bn2(self.conv2(x))))  # 10→5
        x = self.pool(self.act(self.bn3(self.conv3(x))))  # 5→2
        x = self.pool(self.act(self.bn4(self.conv4(x))))  # 2→1
        x = x.view(x.size(0), -1)
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        out = self.fc_out(x)
        return out

# %%
class BaselineRegressionLoss(nn.Module):
    """Simple baseline loss for regression.

    - Uses SmoothL1 by default (robust, stable).
    - Assumes targets already normalized (l1,l2,l3 divided by 400 before batching).
    """

    def __init__(self, kind: str = "smoothl1"):
        super().__init__()
        if kind.lower() == "mse":
            self.crit = nn.MSELoss()
        else:
            self.crit = nn.SmoothL1Loss()

    def forward(self, preds: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        return self.crit(preds, targets)

# %%
# -----------------------------
# Minimal usage example (sketch)
# -----------------------------
# import torch.optim as optim
# model = EllipseRegressionModel().to(device)
# loss_fn = BaselineRegressionLoss(kind="smoothl1").to(device)
# opt = optim.Adam(model.parameters(), lr=1e-3)
# for imgs, targets in train_loader:  # student must implement DataLoader
#     imgs, targets = imgs.to(device), targets.to(device)
#     opt.zero_grad()
#     preds = model(imgs)
#     loss = loss_fn(preds, targets)
#     loss.backward()
#     opt.step()
#
# QAT:
# - Fuse (conv,bn,act) where applicable
# - Set qconfig (torch.ao.quantization.get_default_qat_qconfig)
# - prepare_qat(model) → train → convert(model) for inference

# %%
#  Dataset + Dataloader


from dataset import EllipseDataset       # make sure dataset.py is in the same folder as your notebook
from dataloader import create_dataloaders
from torchvision import transforms

#  Update these paths for your local setup
images_dir = "/home/hritik/Desktop/Hritik/Project/Dataset/Ellipses"
annotations_path = "/home/hritik/Desktop/Hritik/Project/Dataset/annotations.json"

#  Transform: Resize to 20×20 and convert to 1-channel (grayscale)
transform = transforms.Compose([
    transforms.Resize((20, 20)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

#  Create dataset and dataloaders
dataset = EllipseDataset(images_dir=images_dir, annotations_path=annotations_path, transform=transform)
train_loader, val_loader, test_loader = create_dataloaders(dataset, batch_size=64, num_workers=4)

print(f"Dataset loaded successfully with {len(dataset)} samples.")
print(f"Train: {len(train_loader.dataset)}, Val: {len(val_loader.dataset)}, Test: {len(test_loader.dataset)}")
# Out:
# Dataset loaded successfully with 1000000 samples.
# Train: 800000, Val: 100000, Test: 100000

# %%
# Device selection (safe GPU/CPU auto-fallback)

import torch


def select_device(min_arch: int = 70) -> torch.device:
    """Return torch.device('cuda') if a usable CUDA GPU exists and meets the
    minimum compute capability (e.g. 70 -> sm_70). Otherwise return CPU.
    """
    if not torch.cuda.is_available():
        return torch.device('cpu')
    try:
        prop = torch.cuda.get_device_properties(0)
        compute = prop.major * 10 + prop.minor
        if compute >= min_arch:
            return torch.device('cuda')
        print(f"GPU {prop.name} compute capability {prop.major}.{prop.minor} < required {min_arch/10:.1f}; using CPU")
        return torch.device('cpu')
    except Exception:
        # fallback to CPU if querying properties fails
        return torch.device('cpu')


def move_batch_to_device(batch: dict, device: torch.device) -> dict:
    """Move all torch.Tensor values in batch (dict) to device; leave others unchanged."""
    return {k: (v.to(device) if isinstance(v, torch.Tensor) else v) for k, v in batch.items()}


# Select device and print recommended pin_memory flag
device = select_device()
print('Selected device ->', device)
pin_memory = (device.type == 'cuda')
print('pin_memory recommended =', pin_memory)


# Safe smoke-check: move model and one batch to device, verify shapes before inference
# This check is defensive: it will not error if cells are run out-of-order.
if 'train_loader' not in globals():
    print('train_loader is not defined. Run the Dataset + Dataloader cell first. Skipping smoke-check.')
else:
    # Only attempt model forward if the model class is defined
    if 'EllipseRegressionModel' in globals():
        try:
            model = EllipseRegressionModel().to(device)
            model.eval()

            # Grab a batch from train_loader
            batch = next(iter(train_loader))

            # Inspect raw shapes before moving
            print('Raw batch shapes: image', batch['image'].shape, 'params', batch['params'].shape)

            # Move tensors in batch to device
            batch = move_batch_to_device(batch, device)
            images = batch['image']
            targets = batch['params']

            # Final device/shape checks
            print('Moved to device:', device)
            print('images device:', images.device, 'targets device:', targets.device)
            print('images shape:', images.shape, 'targets shape:', targets.shape)

            # Optional forward pass check
            with torch.no_grad():
                outputs = model(images)
            print('Forward OK — outputs shape:', outputs.shape)
        except Exception as e:
            import traceback
            print('Error during smoke-check:')
            traceback.print_exc()
    else:
        print('EllipseRegressionModel is not defined. Run the model-definition cell before this smoke-check.')
# Out:
# Selected device -> cuda
# pin_memory recommended = True
# Raw batch shapes: image torch.Size([64, 1, 20, 20]) params torch.Size([64, 5])
# Moved to device: cuda
# images device: cuda:0 targets device: cuda:0
# images shape: torch.Size([64, 1, 20, 20]) targets shape: torch.Size([64, 5])
# Forward OK — outputs shape: torch.Size([64, 5])

# %%
# Helper cell: compute ranges (min/max) for targets before normalization",
# It prefers `train_loader` (batches) if available, otherwise falls back to iterating `dataset`.
# Prints both the dataset-returned (normalized) ranges and denormalized ranges for l1,l2,l3 (×400).

import numpy as np
import torch

def _gather_all_targets():
    if 'train_loader' in globals():
        print('Collecting targets from train_loader (batched)...')
        parts = []
        for batch in train_loader:
            params = batch['params']
            if isinstance(params, torch.Tensor):
                parts.append(params.cpu().numpy())
            else:
                parts.append(np.asarray(params))
        return np.concatenate(parts, axis=0)
    elif 'dataset' in globals():
        print('Collecting targets by iterating dataset (may be slower)...')
        parts = []
        try:
            from tqdm import tqdm
            iterator = range(len(dataset))
            for i in tqdm(iterator, desc='reading dataset'):
                item = dataset[i]
                p = item['params']
                if isinstance(p, torch.Tensor):
                    parts.append(p.cpu().numpy())
                else:
                    parts.append(np.asarray(p))
        except Exception:
            # fallback without tqdm
            for i in range(len(dataset)):
                item = dataset[i]
                p = item['params']
                if isinstance(p, torch.Tensor):
                    parts.append(p.cpu().numpy())
                else:
                    parts.append(np.asarray(p))
        return np.stack(parts, axis=0)
    else:
        raise RuntimeError('Neither `train_loader` nor `dataset` found in globals. Run the Dataset + Dataloader cell first.')

try:
    all_params = _gather_all_targets()
    assert all_params.ndim == 2 and all_params.shape[1] == 5, f'unexpected params shape: {all_params.shape}'

    names = ['cx', 'cy', 'lxx', 'lxy', 'lyy']

    mins = all_params.min(axis=0)
    maxs = all_params.max(axis=0)
    means = all_params.mean(axis=0)
    stds = all_params.std(axis=0)

    print('\nNormalized ranges:')
    for i, name in enumerate(names):
        print(f'  {name:>3}: min={mins[i]:.6g}, max={maxs[i]:.6g}, mean={means[i]:.6g}, std={stds[i]:.6g}')

    # Denormalize l1,l2,l3 by multiplying by 400 (common convention used in this project)
    denorm = all_params.copy()
    denorm[:, 2:5] = denorm[:, 2:5] * 400.0
    mins_d = denorm.min(axis=0)
    maxs_d = denorm.max(axis=0)
    means_d = denorm.mean(axis=0)
    stds_d = denorm.std(axis=0)

    print('\nDenormalized ranges (lxx,lxy,lyy multiplied by 400):')
    for i, name in enumerate(names):
        print(f'  {name:>3}: min={mins_d[i]:.6g}, max={maxs_d[i]:.6g}, mean={means_d[i]:.6g}, std={stds_d[i]:.6g}')

except Exception as e:
    print('Failed to compute target ranges:', e)
    raise
# Out:
# Collecting targets from train_loader (batched)...
#
# Normalized ranges:
#    cx: min=5.33106, max=34.6247, mean=20.0056, std=4.61801
#    cy: min=5.35283, max=34.7364, mean=20.0065, std=4.60593
#   lxx: min=25.0346, max=398.977, mean=136.2, std=59.621
#   lxy: min=25.0031, max=395.514, mean=136.335, std=59.6283
#   lyy: min=-185.593, max=185.856, mean=-0.0444214, std=46.0132
#
# Denormalized ranges (lxx,lxy,lyy multiplied by 400):
#    cx: min=5.33106, max=34.6247, mean=20.0056, std=4.61801
#    cy: min=5.35283, max=34.7364, mean=20.0065, std=4.60593
#   lxx: min=10013.8, max=159591, mean=54478.1, std=23848.9
#   lxy: min=10001.3, max=158205, mean=54535.7, std=23851.6
#   lyy: min=-74237.2, max=74342.5, mean=-17.7684, std=18405.8

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import random

#  Function to compute a,b,theta from covariance matrix 
def ellipse_from_covariance(l1, l2, l3):
    """
    Given covariance matrix elements (l1=lxx, l2=lxy, l3=lyy),
    return (a, b, theta):
    - a: semi-major axis length
    - b: semi-minor axis length
    - theta: orientation angle in degrees
    """
    cov = np.array([[l1, l2],
                    [l2, l3]])

    # Eigen decomposition
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    # Sort eigenvalues descending
    order = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]

    a, b = np.sqrt(eigenvalues)
    theta = np.degrees(np.arctan2(eigenvectors[1, 0], eigenvectors[0, 0]))
    return a, b, theta


#  Visualize few random samples 
num_samples = 5  # how many ellipses to visualize
indices = random.sample(range(len(dataset)), num_samples)

for idx in indices:
    sample = dataset[idx]
    img = sample["image"].permute(1, 2, 0).numpy()
    params = sample["params"].numpy()
    cx, cy = params[0], params[1]
    l1, l2, l3 = params[2], params[3], params[4]

    a, b, theta = ellipse_from_covariance(l1, l2, l3)

    print(f"Image ID: {sample['image_id']}")
    print(f"cx={cx:.2f}, cy={cy:.2f}")
    print(f"lxx={l1:.3f}, lxy={l2:.3f}, lyy={l3:.3f}")
    print(f"Derived: a={a:.3f}, b={b:.3f}, θ={theta:.2f}°\n")

    # Plot image + ellipse outline 
    fig, ax = plt.subplots(figsize=(3, 3))
    ax.imshow(img, cmap="gray")
    ax.set_title(f"ID {sample['image_id']} | θ={theta:.1f}°", fontsize=10)

    # Create the ellipse outline using derived values
    ellipse = patches.Ellipse(
        (cx, cy), width=2*a, height=2*b, angle=theta,
        edgecolor="red", facecolor="none", linewidth=2
    )
    ax.add_patch(ellipse)
    ax.scatter(cx, cy, color="yellow", s=20)  # mark center
    ax.set_axis_off()
    plt.show()
# Out:
# Image ID: 107870
# cx=30.52, cy=21.38
# lxx=32.371, lxy=119.714, lyy=18.819
# Derived: a=12.062, b=nan, θ=-136.62°
# /tmp/ipykernel_6495/2873859933.py:25: RuntimeWarning: invalid value encountered in sqrt
#   a, b = np.sqrt(eigenvalues)
# Image ID: 593379
# cx=20.84, cy=23.18
# lxx=102.799, lxy=202.231, lyy=-20.505
# Derived: a=15.892, b=nan, θ=-143.48°
# Image ID: 107328
# cx=27.56, cy=22.73
# lxx=100.054, lxy=89.629, lyy=62.716
# Derived: a=13.151, b=nan, θ=-140.88°
# Image ID: 81289
# cx=14.85, cy=21.91
# lxx=99.616, lxy=73.563, lyy=37.513
# Derived: a=12.182, b=nan, θ=-146.44°
# Image ID: 411672
# cx=32.32, cy=19.47
# lxx=37.459, lxy=138.719, lyy=12.333
# Derived: a=12.813, b=nan, θ=-137.59°

# %%
#  Baseline Inference  (GPU if available, else CPU)

import torch
import sys

# Determine device: prefer an existing `device` or `select_device()` helper if present,
# otherwise choose CUDA if available else CPU. This prints informative messages.
_device = globals().get('device', None)
if _device is not None:
    device = _device
else:
    sel = globals().get('select_device', None)
    if callable(sel):
        try:
            device = sel()
        except Exception as e:
            print('select_device() failed, falling back to torch defaults:', e)
            device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    else:
        # No helper: prefer CUDA if available. Print device properties when possible.
        if torch.cuda.is_available():
            try:
                prop = torch.cuda.get_device_properties(0)
                print(f'CUDA available: {prop.name} compute {prop.major}.{prop.minor}')
            except Exception as e:
                print('Could not query CUDA device properties:', e)
            device = torch.device('cuda')
        else:
            device = torch.device('cpu')

print(f'Using device: {device}')

# Initialize model and move to the selected device
model = EllipseRegressionModel().to(device)
model.eval()

# Load a small batch and move it to the selected device
batch = next(iter(train_loader))
batch = move_batch_to_device(batch, device)
images = batch['image']
targets = batch['params']

# Run inference
with torch.no_grad():
    outputs = model(images)

print(' Inference ran successfully!')
print('Predictions shape:', outputs.shape)
print('Sample prediction:', outputs[0])
print('Sample target:', targets[0])
# Out:
# Using device: cuda
#  Inference ran successfully!
# Predictions shape: torch.Size([64, 5])
# Sample prediction: tensor([ 0.0296, -0.0068, -0.0255, -0.0462,  0.0093], device='cuda:0')
# Sample target: tensor([ 19.8738,  19.2785, 209.3574, 151.8232,  56.8773], device='cuda:0')

# %%
# Evaluation: MAE / RMSE + diagnostic plots
# Runs the model over `val_loader` and prints per-output and overall metrics.
import torch
import numpy as np

# Determine device (prefer existing `device` or fall back)
device = globals().get('device') if globals().get('device', None) is not None else (select_device() if globals().get('select_device', None) else (torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
print('Evaluation will run on device:', device)

model = EllipseRegressionModel().to(device)
model.eval()

# Collect predictions and targets (keep on CPU to reduce GPU memory)
preds_list = []
tgt_list = []
with torch.no_grad():
    for batch in val_loader:
        batch = move_batch_to_device(batch, device)
        out = model(batch['image'])
        preds_list.append(out.cpu())
        tgt_list.append(batch['params'].cpu())

preds = torch.cat(preds_list, dim=0)
tgt = torch.cat(tgt_list, dim=0)

# Per-output metrics
diff = preds - tgt
mae_per = torch.mean(diff.abs(), dim=0)
rmse_per = torch.sqrt(torch.mean(diff**2, dim=0))
print('MAE per output (cx,cy,lxx,lxy,lyy):', mae_per.tolist())
print('RMSE per output (cx,cy,lxx,lxy,lyy):', rmse_per.tolist())
print('Mean MAE:', float(mae_per.mean()), 'Mean RMSE:', float(rmse_per.mean()))

# If l1/l2/l3 were normalized by 400 in the dataset, show denormalized metrics for those outputs
try:
    # assume normalization used: l1,l2,l3 divided by 400
    denorm_preds = preds.clone()
    denorm_tgt = tgt.clone()
    denorm_preds[:,2:5] *= 400.0
    denorm_tgt[:,2:5] *= 400.0
    denorm_diff = denorm_preds - denorm_tgt
    denorm_mae = torch.mean(denorm_diff.abs(), dim=0)
    denorm_rmse = torch.sqrt(torch.mean(denorm_diff**2, dim=0))
    print('Denorm MAE (lxx,lxy,lyy) [units]:', denorm_mae[2:5].tolist())
    print('Denorm RMSE (lxx,lxy,lyy) [units]:', denorm_rmse[2:5].tolist())
except Exception:
    pass

# Print a small table of samples: true vs pred for first 5 examples
n_show = min(5, preds.shape[0])
print(f'\nFirst {n_show} examples (pred -> target):')
for i in range(n_show):
    print(f'[{i}] pred:', preds[i].numpy(), ' target:', tgt[i].numpy())

# Diagnostic plots (scatter + residual histograms) if matplotlib is available
try:
    import matplotlib.pyplot as plt
    import math
    preds_np = preds.numpy()
    tgt_np = tgt.numpy()
    # Scatter for cx and cx residuals
    fig, axes = plt.subplots(2, 3, figsize=(15, 8))
    axes = axes.ravel()
    labels = ['cx', 'cy', 'lxx', 'lxy', 'lyy']
    for j in range(5):
        axes[j].scatter(tgt_np[:, j], preds_np[:, j], s=3, alpha=0.4)
        axes[j].set_title(labels[j])
        axes[j].set_xlabel('true')
        axes[j].set_ylabel('pred')
    plt.tight_layout()
    plt.show()
    # Residual histograms for each output (include cx and cy as well)
    fig2, axes2 = plt.subplots(1, 5, figsize=(20, 3))
    for k in range(5):
        axes2[k].hist((preds_np[:, k]-tgt_np[:, k]), bins=80)
        axes2[k].set_title(f'residual {labels[k]}')
    plt.tight_layout(); plt.show()
except Exception as e:
    print('Matplotlib unavailable or plotting failed:', e)

print('Evaluation complete.')
# Out:
# Evaluation will run on device: cpu
# MAE per output (cx,cy,lxx,lxy,lyy): [20.019699096679688, 19.959365844726562, 136.2263641357422, 136.44381713867188, 34.02322006225586]
# RMSE per output (cx,cy,lxx,lxy,lyy): [20.5445499420166, 20.483917236328125, 148.67153930664062, 148.89068603515625, 46.005924224853516]
# Mean MAE: 69.3344955444336 Mean RMSE: 76.91932678222656
# Denorm MAE (lxx,lxy,lyy) [units]: [54490.54296875, 54577.51953125, 13609.2900390625]
# Denorm RMSE (lxx,lxy,lyy) [units]: [59468.61328125, 59556.26953125, 18402.37109375]
#
# First 5 examples (pred -> target):
# [0] pred: [-0.01277219  0.05290179 -0.05705794  0.03056042 -0.05765831]  target: [ 17.053455  19.505548 122.48734  301.4743   -37.78536 ]
# [1] pred: [-0.01268592  0.05314273 -0.05754078  0.0309974  -0.05755211]  target: [ 20.991274  22.024527 286.93402  314.30096  -33.54171 ]
# [2] pred: [-0.01266236  0.05330138 -0.05789994  0.03064733 -0.05780177]  target: [ 18.624212  16.483942  60.108997 205.25464  -65.70538 ]
# [3] pred: [-0.01267683  0.05311855 -0.05705102  0.03107259 -0.05777516]  target: [ 16.649616  21.587492 165.50395  125.854836 -32.789257]
# [4] pred: [-0.01247111  0.05335416 -0.05760573  0.03110466 -0.05764592]  target: [ 13.280742  22.88325   96.367935 215.56789   19.4182  ]
# Evaluation complete.

# %%
#  FP32 TRAINING LOOP 

import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

# Step: Device selection (safe fallback)
GPU_MIN_ARCH = globals().get('GPU_MIN_ARCH', 70)
try:
    device = select_device(min_arch=GPU_MIN_ARCH)
except Exception as e:
    print('select_device() unavailable or failed, using torch default:', e)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

globals()['device'] = device
print("Using device:", device)

# Step: Model and Loss
model = EllipseRegressionModel().to(device)

# Use SmoothL1Loss if available, else fallback to MSELoss
try:
    loss_fn = nn.SmoothL1Loss()
    loss_name = "SmoothL1Loss"
except AttributeError:
    loss_fn = nn.MSELoss()
    loss_name = "MSELoss"

loss_fn = loss_fn.to(device)
print("Using loss:", loss_name)

# Step: Optimizer and Scheduler
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)

# Reduce learning rate when validation loss stops improving
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)
if hasattr(scheduler, 'verbose'):
    scheduler.verbose = True  # only works on newer PyTorch versions

# Step: Training parameters
num_epochs = 150
best_val_loss = float('inf')
best_epoch = 0

print("\n Starting FP32 training...\n")

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    #  Training Loop 
    for batch in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
        images = batch['image'].to(device)
        targets = batch['params'].to(device)

        # Normalize covariance matrix terms (l1, l2, l3)
        targets_norm = targets.clone()
        targets_norm[:, 2:] /= 400.0

        optimizer.zero_grad()
        preds = model(images)
        loss = loss_fn(preds, targets_norm)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    avg_train_loss = running_loss / len(train_loader.dataset)

    #  Validation Loop
    model.eval()
    val_loss_total = 0.0
    with torch.no_grad():
        for batch in val_loader:
            images = batch['image'].to(device)
            targets = batch['params'].to(device)

            tgt_norm = targets.clone()
            tgt_norm[:, 2:] /= 400.0

            preds = model(images)
            vloss = loss_fn(preds, tgt_norm)
            val_loss_total += vloss.item() * images.size(0)

    avg_val_loss = val_loss_total / len(val_loader.dataset)

    # Scheduler update (adjust learning rate)
    scheduler.step(avg_val_loss)
    print(f"→ Scheduler adjusted LR: {optimizer.param_groups[0]['lr']:.2e}")

    #  Epoch Summary 
    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {avg_train_loss:.6f} | Val Loss: {avg_val_loss:.6f}")

    # Save best model 
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_epoch = epoch + 1
        torch.save(model.state_dict(), "ellipse_fp32_best.pth")
        print(f" Saved best model at epoch {best_epoch} (val loss {best_val_loss:.6f})")

print(f"\n Training complete! Best val loss {best_val_loss:.6f} at epoch {best_epoch}.")
# Out:
# GPU NVIDIA GeForce MX330 compute capability 6.1 < required 7.0; using CPU
# Using device: cpu
# Using loss: SmoothL1Loss
#
#  Starting FP32 training...
# Epoch 1/150:   1%|          | 116/12500 [00:06<11:00, 18.76it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 65
#      63     loss = loss_fn(preds, targets_norm)
#      64     loss.backward()
# ---> 65     optimizer.step()
#      67     running_loss += loss.item() * images.size(0)
#      69 avg_train_loss = running_loss / len(train_loader.dataset)
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File ~/miniconda3/envs/ellipse-regression-project/lib/python3.13/site-packages/torch/optim/adam.py:535, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     533         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     534     else:
# --> 535         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     537     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     539 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
# Cell: Save FP32 Trained Model


# Save final model (last epoch)
torch.save(model.state_dict(), "ellipse_fp32_final.pth")
print("FP32 model (final epoch) saved as 'ellipse_fp32_final.pth'")
# Out:
# FP32 model (final epoch) saved as 'ellipse_fp32_final.pth'

# %%
#  Cell: Load FP32 Model for Inference (with target normalization)

import torch

# Define the model architecture (must match training)
model = EllipseRegressionModel()

# Load saved weights
checkpoint_path = "ellipse_fp32_best.pth"  # or "ellipse_fp32_final.pth"
model.load_state_dict(torch.load(checkpoint_path, map_location=device))  # device = 'cpu' or 'cuda'

# Move model to the selected device and set to eval
model = model.to(device)
model.eval()

print(f"FP32 model loaded from '{checkpoint_path}' and ready for inference on device {device}.")

# Quick inference test on one batch 
batch = next(iter(test_loader))  # use your test DataLoader

images = batch["image"].to(device)
targets = batch["params"].to(device)

# 🔹 Normalize l1, l2, l3 of the targets (same scaling used during training)
targets[:, 2:] = targets[:, 2:] / 400.0

# Run inference
with torch.no_grad():
    preds = model(images)

# Display results 
print("Predictions shape:", preds.shape)
print("\nFirst 5 predictions (normalized):")
print(preds[:5])

print("\nFirst 5 targets (normalized):")
print(targets[:5])

# Optional: Mean absolute difference just for a quick sanity check
mae = torch.mean(torch.abs(preds - targets), dim=0)
print("\nQuick MAE per parameter (cx, cy, lxx, lxy, lyy):", mae.cpu().numpy())
# Out:
# FP32 model loaded from 'ellipse_fp32_best.pth' and ready for inference on device cpu.
# Predictions shape: torch.Size([64, 5])
#
# First 5 predictions (normalized):
# tensor([[ 2.4233e+01,  2.4755e+01,  4.0703e-01,  2.4775e-01, -2.5006e-01],
#         [ 1.4269e+01,  2.1187e+01,  4.1561e-01,  2.8922e-01, -1.4452e-01],
#         [ 2.0670e+01,  1.1435e+01,  2.3304e-01,  2.3785e-01,  1.6638e-02],
#         [ 2.1071e+01,  2.6063e+01,  7.7190e-02,  3.4772e-01, -1.7780e-03],
#         [ 2.0162e+01,  2.6798e+01,  3.7263e-01,  9.6187e-02, -2.2180e-02]])
#
# First 5 targets (normalized):
# tensor([[ 2.3987e+01,  2.4945e+01,  4.2623e-01,  2.4202e-01, -2.2954e-01],
#         [ 1.4291e+01,  2.1354e+01,  4.1769e-01,  3.0735e-01, -1.4953e-01],
#         [ 2.0777e+01,  1.1279e+01,  2.1795e-01,  2.2688e-01,  3.5830e-02],
#         [ 2.0906e+01,  2.6132e+01,  7.4180e-02,  3.5909e-01,  7.5796e-04],
#         [ 1.9859e+01,  2.6889e+01,  3.8041e-01,  8.3562e-02, -1.1577e-02]])
#
# Quick MAE per parameter (cx, cy, lxx, lxy, lyy): [0.18635255 0.13579728 0.01288562 0.01567286 0.01288425]

# %%
# Cell: Evaluate FP32 Model + Δ (Delta) Histograms


import torch
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

DENORM = 400.0  # the factor used during training: targets[:,2:] /= DENORM

model.eval()

all_preds = []
all_targets = []

# Collect predictions and targets (raw from model and dataset)
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating FP32 model"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)   # dataset-provided values (likely raw)
        preds = model(images)                  # model outputs (likely normalized for l1,l2,l3)

        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

# Concatenate
all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# Diagnostics: inspect typical magnitudes for covariance components
pred_l_med = np.median(np.abs(all_preds[:, 2:]), axis=0)
tgt_l_med = np.median(np.abs(all_targets[:, 2:]), axis=0)
print("Median magnitudes (pred l1,l2,l3):", pred_l_med)
print("Median magnitudes (tgt  l1,l2,l3):", tgt_l_med)

# Heuristic to decide if values are normalized (≈O(1)) or already denormalized (>>1)
def maybe_denorm(arr, name):
    """If arr's median magnitude is small (<=5), assume it's normalized and denorm it."""
    med = np.median(np.abs(arr))
    if med <= 5.0:
        print(f"-> {name} looks normalized (median {med:.3f}); applying *{DENORM} denorm factor.")
        return arr * DENORM, True
    else:
        print(f"-> {name} looks already denormalized (median {med:.3f}); leaving as-is.")
        return arr, False

# Apply detection & denormalization for covariance parts separately for preds & targets
# Work on copies to avoid accidental double multiplication
preds_work = all_preds.copy()
targs_work = all_targets.copy()

# Denormalize l1,l2,l3 if needed
preds_work[:, 2:], pred_denormed = maybe_denorm(preds_work[:, 2:], "predictions l")
targs_work[:, 2:], targ_denormed = maybe_denorm(targs_work[:, 2:], "targets l")

# (Optional) If cx/cy appear normalized (very small), print a warning; we don't auto-scale cx/cy
cx_med_pred = np.median(np.abs(preds_work[:,0]))
cx_med_targ = np.median(np.abs(targs_work[:,0]))
print(f"Median cx pred={cx_med_pred:.3f}, tgt={cx_med_targ:.3f}")
if np.median(np.abs(preds_work[:, :2])) <= 5.0 and np.median(np.abs(all_targets[:, :2])) > 5.0:
    print("Note: predictions cx/cy look small while targets are large — check coordinate frames.")
# We avoid guessing for cx/cy scaling automatically to prevent incorrect rescaling.

# Now compute absolute differences (denormalized)
delta = np.abs(preds_work - targs_work)

# Compute MAE and RMSE based on the (now) denormalized arrays
mae_per_output = np.mean(delta, axis=0)
rmse_per_output = np.sqrt(np.mean((preds_work - targs_work) ** 2, axis=0))
mean_mae = np.mean(mae_per_output)
mean_rmse = np.mean(rmse_per_output)

print("\nMAE per output (cx, cy, lxx, lxy, lyy) [denorm units]:", mae_per_output)
print("RMSE per output (cx, cy, lxx, lxy, lyy) [denorm units]:", rmse_per_output)
print(f"Mean MAE: {mean_mae:.6f}, Mean RMSE: {mean_rmse:.6f}\n")

# Plot histograms of absolute errors (Δ)
output_names = ["Δcx", "Δcy", "Δlxx", "Δlxy", "Δlyy"]
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, name in enumerate(output_names):
    axes[i].hist(delta[:, i], bins=60, color="steelblue", alpha=0.8)
    axes[i].set_title(f"{name}  (|Pred - Target|)")
    axes[i].set_xlabel("Absolute Error")
    axes[i].set_ylabel("Count")
    axes[i].grid(True, linestyle="--", alpha=0.4)

# Hide extra subplot
if len(output_names) < len(axes):
    for j in range(len(output_names), len(axes)):
        axes[j].axis("off")

plt.tight_layout()
plt.show()

# Print summary stats
for i, name in enumerate(output_names):
    print(f"{name}: mean Δ={delta[:, i].mean():.3f}, std={delta[:, i].std():.3f}, max Δ={delta[:, i].max():.3f}")
# Out:
# Evaluating FP32 model: 100%|██████████| 1563/1563 [00:29<00:00, 53.32it/s]
# Median magnitudes (pred l1,l2,l3): [0.31559765 0.32948142 0.06284426]
# Median magnitudes (tgt  l1,l2,l3): [128.21736 128.37051  25.67974]
# -> predictions l looks normalized (median 0.249); applying *400.0 denorm factor.
# -> targets l looks already denormalized (median 99.079); leaving as-is.
# Median cx pred=20.044, tgt=20.003
#
# MAE per output (cx, cy, lxx, lxy, lyy) [denorm units]: [0.17240979 0.17238401 6.1595716  6.5444627  4.956503  ]
# RMSE per output (cx, cy, lxx, lxy, lyy) [denorm units]: [0.22326817 0.22294874 8.067955   8.37421    6.45905   ]
# Mean MAE: 3.601066, Mean RMSE: 4.669486
# Δcx: mean Δ=0.172, std=0.142, max Δ=1.557
# Δcy: mean Δ=0.172, std=0.141, max Δ=3.553
# Δlxx: mean Δ=6.160, std=5.211, max Δ=73.710
# Δlxy: mean Δ=6.544, std=5.225, max Δ=79.884
# Δlyy: mean Δ=4.957, std=4.142, max Δ=63.416

# %%
# Cell: Evaluate FP32 Model — MAE, RMSE, r, R²


import torch
import numpy as np
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr

model.eval()

all_preds = []
all_targets = []

# Collect predictions and targets from test set
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating model"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        
        preds = model(images)
        
        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

# Concatenate and convert to numpy
all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# Denormalize covariance terms (l1, l2, l3)
all_preds[:, 2:] *= 400.0
#all_targets[:, 2:] *= 400.0

# Compute metrics
mae = mean_absolute_error(all_targets, all_preds, multioutput='raw_values')
rmse = np.sqrt(mean_squared_error(all_targets, all_preds, multioutput='raw_values'))
r2 = r2_score(all_targets, all_preds, multioutput='raw_values')

pearson_r = []
for i in range(all_preds.shape[1]):
    r, _ = pearsonr(all_targets[:, i], all_preds[:, i])
    pearson_r.append(r)
pearson_r = np.array(pearson_r)

# Pretty report
output_names = ["cx", "cy", "lxx", "lxy", "lyy"]

print("\nMODEL PERFORMANCE METRICS \n")
for i, name in enumerate(output_names):
    print(f"{name}:")
    print(f"  MAE   = {mae[i]:.4f}")
    print(f"  RMSE  = {rmse[i]:.4f}")
    print(f"  r     = {pearson_r[i]:.4f}")
    print(f"  R²    = {r2[i]:.4f}")
    #print("-" * 35)

print(f"\nMean MAE  : {mae.mean():.4f}")
print(f"Mean RMSE : {rmse.mean():.4f}")
print(f"Mean r    : {pearson_r.mean():.4f}")
print(f"Mean R²   : {r2.mean():.4f}")
# Out:
# Evaluating model: 100%|██████████| 1563/1563 [00:29<00:00, 53.46it/s]
# MODEL PERFORMANCE METRICS
#
# cx:
#   MAE   = 0.1724
#   RMSE  = 0.2233
#   r     = 0.9989
#   R²    = 0.9977
# cy:
#   MAE   = 0.1724
#   RMSE  = 0.2229
#   r     = 0.9989
#   R²    = 0.9977
# lxx:
#   MAE   = 6.1596
#   RMSE  = 8.0680
#   r     = 0.9913
#   R²    = 0.9817
# lxy:
#   MAE   = 6.5445
#   RMSE  = 8.3742
#   r     = 0.9916
#   R²    = 0.9802
# lyy:
#   MAE   = 4.9565
#   RMSE  = 6.4591
#   r     = 0.9905
#   R²    = 0.9802
#
# Mean MAE  : 3.6011
# Mean RMSE : 4.6695
# Mean r    : 0.9942
# Mean R²   : 0.9875

# %%
# Evaluate Model — Relative Error (%)


import numpy as np
import torch
from tqdm import tqdm

model.eval()

all_preds = []
all_targets = []

# Collect predictions and targets from test set
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Collecting predictions"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        
        preds = model(images)
        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

# Concatenate
all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# Denormalize covariance components (l1, l2, l3)
all_preds[:, 2:] *= 400.0
#all_targets[:, 2:] *= 400.0

# Compute absolute errors
abs_error = np.abs(all_preds - all_targets)

# Compute relative errors (%)
rel_error = abs_error / (np.abs(all_targets) + 1e-8) * 100  # add small epsilon to avoid division by zero

# Summary stats
output_names = ["cx", "cy", "lxx", "lxy", "lyy"]
for i, name in enumerate(output_names):
    mean_rel = np.mean(rel_error[:, i])
    max_rel = np.max(rel_error[:, i])
    print(f"{name}: mean relative error = {mean_rel:.2f}%") #, max relative error = {max_rel:.2f}%")
# Out:
# Collecting predictions: 100%|██████████| 1563/1563 [00:31<00:00, 49.88it/s]
# cx: mean relative error = 0.92%
# cy: mean relative error = 0.92%
# lxx: mean relative error = 5.22%
# lxy: mean relative error = 5.82%
# lyy: mean relative error = 691.00%

# %%
# Initialize from FP32 weights (for QAT)


import torch
from brevitas.nn import QuantConv2d, QuantLinear, QuantReLU

# Load FP32 weights
fp32_checkpoint = "ellipse_fp32_best.pth"
fp32_model = EllipseRegressionModel()
fp32_model.load_state_dict(torch.load(fp32_checkpoint, map_location='cpu'))
fp32_model.eval()

print(f"Loaded FP32 weights from '{fp32_checkpoint}'")
# Out:
# Loaded FP32 weights from 'ellipse_fp32_best.pth'

# %%
from brevitas.nn import QuantConv2d, QuantLinear, QuantReLU
from brevitas.quant import IntWeightPerTensorFloat, IntActPerTensorFloat
import torch.nn as nn

class QuantizedEllipseRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()

        BW = 4  # <<< QAT-4

        self.conv1 = QuantConv2d(
            1, 32, kernel_size=3, padding=1,
            weight_bit_width=BW, bias=False,
            weight_quant=IntWeightPerTensorFloat
        )
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = QuantConv2d(
            32, 64, kernel_size=3, padding=1,
            weight_bit_width=BW, bias=False,
            weight_quant=IntWeightPerTensorFloat
        )
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = QuantConv2d(
            64, 128, kernel_size=3, padding=1,
            weight_bit_width=BW, bias=False,
            weight_quant=IntWeightPerTensorFloat
        )
        self.bn3 = nn.BatchNorm2d(128)

        self.conv4 = QuantConv2d(
            128, 256, kernel_size=3, padding=1,
            weight_bit_width=BW, bias=False,
            weight_quant=IntWeightPerTensorFloat
        )
        self.bn4 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(2)

        # activation quant at 4-bit as well
        self.act = QuantReLU(bit_width=BW, act_quant=IntActPerTensorFloat)

        self.fc1 = QuantLinear(256*1*1, 512, weight_bit_width=BW, bias=False, weight_quant=IntWeightPerTensorFloat)
        self.fc2 = QuantLinear(512, 256, weight_bit_width=BW, bias=False, weight_quant=IntWeightPerTensorFloat)
        self.fc_out = QuantLinear(256, 5, weight_bit_width=BW, bias=False, weight_quant=IntWeightPerTensorFloat)

    def forward(self, x):
        x = self.pool(self.act(self.bn1(self.conv1(x))))
        x = self.pool(self.act(self.bn2(self.conv2(x))))
        x = self.pool(self.act(self.bn3(self.conv3(x))))
        x = self.pool(self.act(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        return self.fc_out(x)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from brevitas.nn import QuantConv2d, QuantLinear, QuantReLU
# ----> 2 from brevitas.quant import IntWeightPerTensorFloat, IntActPerTensorFloat
#       3 import torch.nn as nn
#       5 class QuantizedEllipseRegressionModel(nn.Module):
#
# ImportError: cannot import name 'IntWeightPerTensorFloat' from 'brevitas.quant' (/home/hritik/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/quant/__init__.py)

# %%
from brevitas.nn import QuantConv2d, QuantLinear, QuantReLU
import torch.nn as nn

# --- robust quantizer import across Brevitas versions ---
try:
    # many notebooks use this (your QAT8 likely used it)
    from brevitas.quant import Int8WeightPerTensorFloat as WeightQuant
except Exception:
    try:
        # some versions keep it here
        from brevitas.quant.scaled_int import Int8WeightPerTensorFloat as WeightQuant
    except Exception:
        WeightQuant = None  # fallback: don't pass weight_quant explicitly

class QuantizedEllipseRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()

        BW = 4  # <<< QAT-4

        # If WeightQuant is available, use it; otherwise rely on default QuantConv2d quant behavior
        wq_kwargs = {} if WeightQuant is None else {"weight_quant": WeightQuant}

        self.conv1 = QuantConv2d(1, 32, kernel_size=3, padding=1,
                                 weight_bit_width=BW, bias=False, **wq_kwargs)
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = QuantConv2d(32, 64, kernel_size=3, padding=1,
                                 weight_bit_width=BW, bias=False, **wq_kwargs)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = QuantConv2d(64, 128, kernel_size=3, padding=1,
                                 weight_bit_width=BW, bias=False, **wq_kwargs)
        self.bn3 = nn.BatchNorm2d(128)

        self.conv4 = QuantConv2d(128, 256, kernel_size=3, padding=1,
                                 weight_bit_width=BW, bias=False, **wq_kwargs)
        self.bn4 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(2)

        # Activation quantization at 4-bit (this works in most Brevitas versions without extra imports)
        self.act = QuantReLU(bit_width=BW)

        self.fc1 = QuantLinear(256*1*1, 512, weight_bit_width=BW, bias=False, **wq_kwargs)
        self.fc2 = QuantLinear(512, 256, weight_bit_width=BW, bias=False, **wq_kwargs)
        self.fc_out = QuantLinear(256, 5, weight_bit_width=BW, bias=False, **wq_kwargs)

    def forward(self, x):
        x = self.pool(self.act(self.bn1(self.conv1(x))))
        x = self.pool(self.act(self.bn2(self.conv2(x))))
        x = self.pool(self.act(self.bn3(self.conv3(x))))
        x = self.pool(self.act(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        return self.fc_out(x)

# %%
#  Initialize Quantized Model from FP32 Weights


import torch

# Load your trained FP32 model weights (make sure path is correct)
fp32_model_path = "ellipse_fp32_best.pth"
fp32_model = EllipseRegressionModel().to(device)
fp32_model.load_state_dict(torch.load(fp32_model_path, map_location=device))
fp32_model.eval()

# Initialize quantized model
q_model = QuantizedEllipseRegressionModel().to(device)

# Copy FP32 weights layer by layer
with torch.no_grad():
    # Conv layers
    q_model.conv1.weight.copy_(fp32_model.conv1.weight)
    q_model.conv2.weight.copy_(fp32_model.conv2.weight)
    q_model.conv3.weight.copy_(fp32_model.conv3.weight)
    q_model.conv4.weight.copy_(fp32_model.conv4.weight)

    # BatchNorm layers
    q_model.bn1.load_state_dict(fp32_model.bn1.state_dict())
    q_model.bn2.load_state_dict(fp32_model.bn2.state_dict())
    q_model.bn3.load_state_dict(fp32_model.bn3.state_dict())
    q_model.bn4.load_state_dict(fp32_model.bn4.state_dict())

    # Fully connected layers
    q_model.fc1.weight.copy_(fp32_model.fc1.weight)
    q_model.fc2.weight.copy_(fp32_model.fc2.weight)
    q_model.fc_out.weight.copy_(fp32_model.fc_out.weight)

print("Quantized model initialized with FP32 pretrained weights.")
# Out:
# Quantized model initialized with FP32 pretrained weights.

# %%
# Quantization-Aware Training (QAT)


import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

# QAT Setup 
num_epochs_qat = 30  # fewer epochs than FP32 training (since weights are initialized)
learning_rate_qat = 1e-4

# Define loss and optimizer
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(q_model.parameters(), lr=learning_rate_qat, weight_decay=1e-5)

# Optional: learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

best_val_loss = float('inf')

print("Starting Quantization-Aware Training...")

for epoch in range(num_epochs_qat):
    q_model.train()
    running_loss = 0.0

    # --- Training loop ---
    for batch in tqdm(train_loader, desc=f"QAT Epoch {epoch+1}/{num_epochs_qat}"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        targets_norm = targets.clone()
        targets_norm[:, 2:] = targets_norm[:, 2:] / 400.0  # normalize l1,l2,l3

        optimizer.zero_grad()
        preds = q_model(images)
        loss = criterion(preds, targets_norm)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    avg_train_loss = running_loss / len(train_loader.dataset)

    # --- Validation ---
    q_model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch in val_loader:
            images = batch["image"].to(device)
            targets = batch["params"].to(device)
            tgt_norm = targets.clone()
            tgt_norm[:, 2:] = tgt_norm[:, 2:] / 400.0
            preds = q_model(images)
            loss = criterion(preds, tgt_norm)
            val_loss += loss.item() * images.size(0)

    avg_val_loss = val_loss / len(val_loader.dataset)
    scheduler.step(avg_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs_qat}]  Train Loss: {avg_train_loss:.6f}  |  Val Loss: {avg_val_loss:.6f}")

    # --- Save best model ---
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(q_model.state_dict(), "ellipse_qat4_best.pth")
        print(f"Saved best QAT model (val loss = {best_val_loss:.6f})")

print("QAT training complete!")
# Out:
# Starting Quantization-Aware Training...
# QAT Epoch 1/30:   0%|          | 0/12500 [00:00<?, ?it/s]/home/hritik/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/_tensor.py:1630: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /pytorch/c10/core/TensorImpl.h:1971.)
#   return super().rename(names)
# QAT Epoch 1/30: 100%|██████████| 12500/12500 [01:48<00:00, 115.57it/s]
# Epoch [1/30]  Train Loss: 0.027396  |  Val Loss: 0.019304
# Saved best QAT model (val loss = 0.019304)
# QAT Epoch 2/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.51it/s]
# Epoch [2/30]  Train Loss: 0.021469  |  Val Loss: 0.021046
# QAT Epoch 3/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.02it/s]
# Epoch [3/30]  Train Loss: 0.019952  |  Val Loss: 0.018787
# Saved best QAT model (val loss = 0.018787)
# QAT Epoch 4/30: 100%|██████████| 12500/12500 [01:49<00:00, 114.01it/s]
# Epoch [4/30]  Train Loss: 0.019338  |  Val Loss: 0.020225
# QAT Epoch 5/30: 100%|██████████| 12500/12500 [01:47<00:00, 115.78it/s]
# Epoch [5/30]  Train Loss: 0.018104  |  Val Loss: 0.016682
# Saved best QAT model (val loss = 0.016682)
# QAT Epoch 6/30: 100%|██████████| 12500/12500 [01:47<00:00, 115.77it/s]
# Epoch [6/30]  Train Loss: 0.017964  |  Val Loss: 0.021692
# QAT Epoch 7/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.04it/s]
# Epoch [7/30]  Train Loss: 0.017496  |  Val Loss: 0.018720
# QAT Epoch 8/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.34it/s]
# Epoch [8/30]  Train Loss: 0.017646  |  Val Loss: 0.018085
# QAT Epoch 9/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.49it/s]
# Epoch [9/30]  Train Loss: 0.017042  |  Val Loss: 0.017061
# QAT Epoch 10/30: 100%|██████████| 12500/12500 [01:45<00:00, 118.34it/s]
# Epoch [10/30]  Train Loss: 0.017354  |  Val Loss: 0.017302
# QAT Epoch 11/30: 100%|██████████| 12500/12500 [01:46<00:00, 117.85it/s]
# Epoch [11/30]  Train Loss: 0.017253  |  Val Loss: 0.019174
# QAT Epoch 12/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.77it/s]
# Epoch [12/30]  Train Loss: 0.015756  |  Val Loss: 0.014908
# Saved best QAT model (val loss = 0.014908)
# QAT Epoch 13/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.10it/s]
# Epoch [13/30]  Train Loss: 0.015677  |  Val Loss: 0.016061
# QAT Epoch 14/30: 100%|██████████| 12500/12500 [01:48<00:00, 115.70it/s]
# Epoch [14/30]  Train Loss: 0.015994  |  Val Loss: 0.015629
# QAT Epoch 15/30: 100%|██████████| 12500/12500 [01:47<00:00, 115.97it/s]
# Epoch [15/30]  Train Loss: 0.015883  |  Val Loss: 0.015356
# QAT Epoch 16/30: 100%|██████████| 12500/12500 [01:44<00:00, 119.31it/s]
# Epoch [16/30]  Train Loss: 0.015961  |  Val Loss: 0.019431
# QAT Epoch 17/30: 100%|██████████| 12500/12500 [01:45<00:00, 118.77it/s]
# Epoch [17/30]  Train Loss: 0.016310  |  Val Loss: 0.017819
# QAT Epoch 18/30: 100%|██████████| 12500/12500 [01:44<00:00, 120.07it/s]
# Epoch [18/30]  Train Loss: 0.015771  |  Val Loss: 0.015549
# QAT Epoch 19/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.47it/s]
# Epoch [19/30]  Train Loss: 0.014618  |  Val Loss: 0.014375
# Saved best QAT model (val loss = 0.014375)
# QAT Epoch 20/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.20it/s]
# Epoch [20/30]  Train Loss: 0.015083  |  Val Loss: 0.013977
# Saved best QAT model (val loss = 0.013977)
# QAT Epoch 21/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.24it/s]
# Epoch [21/30]  Train Loss: 0.014861  |  Val Loss: 0.013457
# Saved best QAT model (val loss = 0.013457)
# QAT Epoch 22/30: 100%|██████████| 12500/12500 [01:44<00:00, 119.54it/s]
# Epoch [22/30]  Train Loss: 0.014740  |  Val Loss: 0.015834
# QAT Epoch 23/30: 100%|██████████| 12500/12500 [01:43<00:00, 121.18it/s]
# Epoch [23/30]  Train Loss: 0.014950  |  Val Loss: 0.015364
# QAT Epoch 24/30: 100%|██████████| 12500/12500 [01:44<00:00, 119.05it/s]
# Epoch [24/30]  Train Loss: 0.015116  |  Val Loss: 0.015260
# QAT Epoch 25/30: 100%|██████████| 12500/12500 [01:45<00:00, 118.37it/s]
# Epoch [25/30]  Train Loss: 0.015512  |  Val Loss: 0.014713
# QAT Epoch 26/30: 100%|██████████| 12500/12500 [01:43<00:00, 120.22it/s]
# Epoch [26/30]  Train Loss: 0.016275  |  Val Loss: 0.015575
# QAT Epoch 27/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.78it/s]
# Epoch [27/30]  Train Loss: 0.015352  |  Val Loss: 0.014616
# QAT Epoch 28/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.14it/s]
# Epoch [28/30]  Train Loss: 0.015021  |  Val Loss: 0.013996
# QAT Epoch 29/30: 100%|██████████| 12500/12500 [01:47<00:00, 116.72it/s]
# Epoch [29/30]  Train Loss: 0.014879  |  Val Loss: 0.015770
# QAT Epoch 30/30: 100%|██████████| 12500/12500 [01:48<00:00, 114.95it/s]
# Epoch [30/30]  Train Loss: 0.015019  |  Val Loss: 0.015507
# QAT training complete!

# %%
# Load Trained QAT Model Checkpoint

import torch

# Load the trained QAT model weights
qat_checkpoint_path = "ellipse_qat4_best.pth"
q_model.load_state_dict(torch.load(qat_checkpoint_path, map_location=device))
q_model.eval()

print(f"✅ Loaded trained QAT model from: {qat_checkpoint_path}")
print(f"   Model is ready for evaluation!")
# Out:
# ✅ Loaded trained QAT model from: ellipse_qat4_best.pth
#    Model is ready for evaluation!

# %%
# Evaluate QAT Model — MAE, RMSE, r, R²


import torch
import numpy as np
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr

q_model.eval()
all_preds, all_targets = [], []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating QAT model"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        preds = q_model(images)
        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# Denormalize covariance terms
all_preds[:, 2:] *= 400.0
#all_targets[:, 2:] *= 400.0

mae = mean_absolute_error(all_targets, all_preds, multioutput='raw_values')
rmse = np.sqrt(mean_squared_error(all_targets, all_preds, multioutput='raw_values'))
r2 = r2_score(all_targets, all_preds, multioutput='raw_values')
pearson_r = [pearsonr(all_targets[:, i], all_preds[:, i])[0] for i in range(5)]

names = ["cx", "cy", "lxx", "lxy", "lyy"]
print("\n QAT MODEL PERFORMANCE \n")
for i, n in enumerate(names):
    print(f"{n}: MAE={mae[i]:.4f}, RMSE={rmse[i]:.4f}, r={pearson_r[i]:.4f}, R²={r2[i]:.4f}")
# Out:
# Evaluating QAT model: 100%|██████████| 1563/1563 [00:08<00:00, 178.71it/s]
#  QAT MODEL PERFORMANCE
#
# cx: MAE=0.1976, RMSE=0.2539, r=0.9985, R²=0.9970
# cy: MAE=0.1980, RMSE=0.2545, r=0.9985, R²=0.9970
# lxx: MAE=11.6192, RMSE=15.0622, r=0.9732, R²=0.9357
# lxy: MAE=11.6502, RMSE=14.7341, r=0.9739, R²=0.9383
# lyy: MAE=17.8093, RMSE=20.2272, r=0.9732, R²=0.8055

# %%
# Evaluate QAT Model + Δ (Delta) Histograms


import torch
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

DENORM = 400.0  # same factor as used during FP32 training

q_model.eval()

all_preds = []
all_targets = []

# Collect predictions and targets from test set
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating QAT model"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        preds = q_model(images)
        
        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

# Concatenate into numpy arrays
all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# Diagnostics: check typical magnitudes for covariance components
pred_l_med = np.median(np.abs(all_preds[:, 2:]), axis=0)
tgt_l_med = np.median(np.abs(all_targets[:, 2:]), axis=0)
print("Median magnitudes (pred lxx,lxy,lyy):", pred_l_med)
print("Median magnitudes (tgt  lxx,lxy,lyy):", tgt_l_med)

def maybe_denorm(arr, name):
    """Auto-detect if normalized; apply denormalization if needed."""
    med = np.median(np.abs(arr))
    if med <= 5.0:
        print(f"-> {name} looks normalized (median {med:.3f}); applying *{DENORM} factor.")
        return arr * DENORM, True
    else:
        print(f"-> {name} looks already denormalized (median {med:.3f}); leaving as-is.")
        return arr, False

# Denormalize covariance terms (l1,l2,l3) if needed
preds_work = all_preds.copy()
targs_work = all_targets.copy()

preds_work[:, 2:], pred_denormed = maybe_denorm(preds_work[:, 2:], "predictions l")
targs_work[:, 2:], targ_denormed = maybe_denorm(targs_work[:, 2:], "targets l")

# Sanity-check cx, cy
cx_med_pred = np.median(np.abs(preds_work[:, 0]))
cx_med_targ = np.median(np.abs(targs_work[:, 0]))
print(f"Median cx pred={cx_med_pred:.3f}, tgt={cx_med_targ:.3f}")

# Compute absolute differences (Δ)
delta = np.abs(preds_work - targs_work)

# Compute MAE and RMSE
mae_per_output = np.mean(delta, axis=0)
rmse_per_output = np.sqrt(np.mean((preds_work - targs_work) ** 2, axis=0))
mean_mae = np.mean(mae_per_output)
mean_rmse = np.mean(rmse_per_output)

print("\nMAE per output (cx, cy, lxx, lxy, lyy) [denorm units]:", mae_per_output)
print("RMSE per output (cx, cy, lxx, lxy, lyy) [denorm units]:", rmse_per_output)
print(f"Mean MAE: {mean_mae:.6f}, Mean RMSE: {mean_rmse:.6f}\n")

# Plot histograms
output_names = ["Δcx", "Δcy", "Δlxx", "Δlxy", "Δlyy"]
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, name in enumerate(output_names):
    axes[i].hist(delta[:, i], bins=60, color="darkorange", alpha=0.8)
    axes[i].set_title(f"{name} (|Pred - Target|)")
    axes[i].set_xlabel("Absolute Error")
    axes[i].set_ylabel("Count")
    axes[i].grid(True, linestyle="--", alpha=0.4)

# Hide any unused subplot
if len(output_names) < len(axes):
    for j in range(len(output_names), len(axes)):
        axes[j].axis("off")

plt.tight_layout()
plt.show()

# Print summary stats
for i, name in enumerate(output_names):
    print(f"{name}: mean Δ={delta[:, i].mean():.3f}, std={delta[:, i].std():.3f}, max Δ={delta[:, i].max():.3f}")
# Out:
# Evaluating QAT model: 100%|██████████| 1563/1563 [00:08<00:00, 191.21it/s]
# Median magnitudes (pred lxx,lxy,lyy): [0.30611765 0.33527172 0.07288516]
# Median magnitudes (tgt  lxx,lxy,lyy): [128.28033  128.39302   25.579325]
# -> predictions l looks normalized (median 0.248); applying *400.0 factor.
# -> targets l looks already denormalized (median 99.366); leaving as-is.
# Median cx pred=19.992, tgt=19.987
#
# MAE per output (cx, cy, lxx, lxy, lyy) [denorm units]: [ 0.19756663  0.19804737 11.619239   11.650156   17.809341  ]
# RMSE per output (cx, cy, lxx, lxy, lyy) [denorm units]: [ 0.253943    0.25447112 15.062172   14.734055   20.227217  ]
# Mean MAE: 8.294870, Mean RMSE: 10.106372
# Δcx: mean Δ=0.198, std=0.160, max Δ=1.857
# Δcy: mean Δ=0.198, std=0.160, max Δ=1.796
# Δlxx: mean Δ=11.619, std=9.585, max Δ=108.494
# Δlxy: mean Δ=11.650, std=9.021, max Δ=76.228
# Δlyy: mean Δ=17.809, std=9.590, max Δ=79.557

# %%
# Evaluate QAT Model — Relative Error (%)


import numpy as np
import torch
from tqdm import tqdm

q_model.eval()

all_preds, all_targets = [], []

# Collect predictions and targets from test set
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating QAT model (relative error)"):
        images = batch["image"].to(device)
        targets = batch["params"].to(device)
        
        preds = q_model(images)
        all_preds.append(preds.cpu())
        all_targets.append(targets.cpu())

# Concatenate and convert to numpy
all_preds = torch.cat(all_preds, dim=0).numpy()
all_targets = torch.cat(all_targets, dim=0).numpy()

# 🔹 Denormalize only the covariance components (l1, l2, l3)
all_preds[:, 2:] *= 400.0
# all_targets[:, 2:] are already in denormalized form (keep as-is)

# Compute absolute errors
abs_error = np.abs(all_preds - all_targets)

# Compute relative errors (%)
rel_error = abs_error / (np.abs(all_targets) + 1e-8) * 100  # avoid divide by zero

# Summary statistics
output_names = ["cx", "cy", "lxx", "lxy", "lyy"]
print("\n QAT MODEL RELATIVE ERROR (%) \n")

for i, name in enumerate(output_names):
    mean_rel = np.mean(rel_error[:, i])
    max_rel = np.max(rel_error[:, i])
    print(f"{name}: mean relative error = {mean_rel:.2f}%")  #, max relative error = {max_rel:.2f}%")
# Out:
# Evaluating QAT model (relative error): 100%|██████████| 1563/1563 [00:08<00:00, 187.60it/s]
#  QAT MODEL RELATIVE ERROR (%)
#
# cx: mean relative error = 1.04%
# cy: mean relative error = 1.05%
# lxx: mean relative error = 10.22%
# lxy: mean relative error = 11.19%
# lyy: mean relative error = 2116.37%

# %%
# Compares FP32 vs QAT on test_loader

import torch, numpy as np
device = globals().get('device', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# Load models (paths may differ)
fp32_path = "ellipse_fp32_best.pth"
qat_path  = "ellipse_qat4_best.pth"

fp32_model = EllipseRegressionModel().to(device)
fp32_model.load_state_dict(torch.load(fp32_path, map_location=device))
fp32_model.eval()

q_model = QuantizedEllipseRegressionModel().to(device)
q_model.load_state_dict(torch.load(qat_path, map_location=device))
q_model.eval()

all_fp32, all_qat, all_tgt = [], [], []
with torch.no_grad():
    for batch in test_loader:
        imgs = batch["image"].to(device)
        t = batch["params"].cpu().numpy()    # assume dataset targets are in original (denorm) units
        p_fp32 = fp32_model(imgs).cpu().numpy()
        p_qat  = q_model(imgs).cpu().numpy()

        # models likely output normalized covariance (l1,l2,l3) -> denormalize if needed
        # if medians small (<=5) assume normalized; otherwise assume already denorm
        def maybe_denorm(arr):
            if np.median(np.abs(arr[:,2:])) <= 5.0:
                arr = arr.copy()
                arr[:,2:] *= 400.0
            return arr

        all_fp32.append(maybe_denorm(p_fp32))
        all_qat.append(maybe_denorm(p_qat))
        all_tgt.append(t)

all_fp32 = np.concatenate(all_fp32, axis=0)
all_qat  = np.concatenate(all_qat, axis=0)
all_tgt  = np.concatenate(all_tgt, axis=0)

# Absolute and relative errors (%)
abs_fp32 = np.abs(all_fp32 - all_tgt)
abs_qat  = np.abs(all_qat  - all_tgt)

rel_fp32 = abs_fp32 / (np.abs(all_tgt) + 1e-8) * 100.0
rel_qat  = abs_qat  / (np.abs(all_tgt) + 1e-8) * 100.0

mae_rel_fp32 = rel_fp32.mean(axis=0)
mae_rel_qat  = rel_qat.mean(axis=0)

mean_fp32 = mae_rel_fp32.mean()
mean_qat  = mae_rel_qat.mean()

improvement_pct = (mae_rel_fp32 - mae_rel_qat) / (mae_rel_fp32 + 1e-12) * 100.0
overall_improv = (mean_fp32 - mean_qat) / (mean_fp32 + 1e-12) * 100.0

names = ["cx","cy","lxx","lxy","lyy"]
print("Per-output mean relative error (%) — FP32  |  QAT   |  Improvement (%)")
for i,n in enumerate(names):
    print(f"{n:>3}: {mae_rel_fp32[i]:7.3f}% -> {mae_rel_qat[i]:7.3f}%   {improvement_pct[i]:7.2f}%")
print(f"\nOverall mean rel error: FP32 {mean_fp32:.3f}%, QAT {mean_qat:.3f}%  → overall improvement {overall_improv:.2f}%")
# Out:
# Per-output mean relative error (%) — FP32  |  QAT   |  Improvement (%)
#  cx:   0.915% ->   1.044%    -14.14%
#  cy:   0.918% ->   1.047%    -14.03%
# lxx:   5.208% ->  10.218%    -96.20%
# lxy:   5.823% ->  11.191%    -92.17%
# lyy: 339.092% -> 2116.293%   -524.11%
#
# Overall mean rel error: FP32 70.391%, QAT 427.959%  → overall improvement -507.97%

# %%
# Cell: Compare FP32 vs QAT — Relative Error for (cx, cy, a, b, θ) - FIXED

import torch
import numpy as np

device = globals().get('device', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# Load models
fp32_path = "ellipse_fp32_best.pth"
qat_path = "ellipse_qat4_best.pth"

fp32_model = EllipseRegressionModel().to(device)
fp32_model.load_state_dict(torch.load(fp32_path, map_location=device))
fp32_model.eval()

q_model = QuantizedEllipseRegressionModel().to(device)
q_model.load_state_dict(torch.load(qat_path, map_location=device))
q_model.eval()

def cov_to_ellipse_params(lxx, lxy, lyy):
    """
    Convert covariance matrix parameters to ellipse parameters (a, b, theta).
    
    Args:
        lxx, lxy, lyy: Covariance matrix components
        
    Returns:
        a: semi-major axis (always positive)
        b: semi-minor axis (always positive)
        theta: orientation angle in degrees [-90, 90]
    """
    # Build covariance matrix
    cov = np.array([[lxx, lxy], [lxy, lyy]])
    
    # Eigenvalue decomposition
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    
    # Sort eigenvalues in descending order
    idx = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[idx]
    eigenvectors = eigenvectors[:, idx]
    
    # Semi-axes lengths (always positive due to sqrt of eigenvalues)
    a = np.sqrt(np.maximum(eigenvalues[0], 0))  # semi-major axis
    b = np.sqrt(np.maximum(eigenvalues[1], 0))  # semi-minor axis
    
    # Orientation angle (in degrees)
    theta = np.degrees(np.arctan2(eigenvectors[1, 0], eigenvectors[0, 0]))
    
    return a, b, theta

# Collect predictions and targets
all_fp32, all_qat, all_tgt = [], [], []

with torch.no_grad():
    for batch in test_loader:
        imgs = batch["image"].to(device)
        t = batch["params"].cpu().numpy()
        
        p_fp32 = fp32_model(imgs).cpu().numpy()
        p_qat = q_model(imgs).cpu().numpy()
        
        # Denormalize covariance terms if needed
        def maybe_denorm(arr):
            if np.median(np.abs(arr[:, 2:])) <= 5.0:
                arr = arr.copy()
                arr[:, 2:] *= 400.0
            return arr
        
        all_fp32.append(maybe_denorm(p_fp32))
        all_qat.append(maybe_denorm(p_qat))
        all_tgt.append(t)

all_fp32 = np.concatenate(all_fp32, axis=0)
all_qat = np.concatenate(all_qat, axis=0)
all_tgt = np.concatenate(all_tgt, axis=0)

# Convert covariance parameters to ellipse parameters (a, b, θ)
n_samples = all_tgt.shape[0]

fp32_ellipse = np.zeros((n_samples, 5))
qat_ellipse = np.zeros((n_samples, 5))
tgt_ellipse = np.zeros((n_samples, 5))

print("Converting covariance parameters to ellipse parameters (a, b, θ)...")

for i in range(n_samples):
    # FP32 predictions
    fp32_ellipse[i, 0:2] = all_fp32[i, 0:2]
    fp32_ellipse[i, 2], fp32_ellipse[i, 3], fp32_ellipse[i, 4] = cov_to_ellipse_params(
        all_fp32[i, 2], all_fp32[i, 3], all_fp32[i, 4]
    )
    
    # QAT predictions
    qat_ellipse[i, 0:2] = all_qat[i, 0:2]
    qat_ellipse[i, 2], qat_ellipse[i, 3], qat_ellipse[i, 4] = cov_to_ellipse_params(
        all_qat[i, 2], all_qat[i, 3], all_qat[i, 4]
    )
    
    # Ground truth targets
    tgt_ellipse[i, 0:2] = all_tgt[i, 0:2]
    tgt_ellipse[i, 2], tgt_ellipse[i, 3], tgt_ellipse[i, 4] = cov_to_ellipse_params(
        all_tgt[i, 2], all_tgt[i, 3], all_tgt[i, 4]
    )

print(" Conversion complete\n")

# Compute absolute errors
abs_fp32 = np.abs(fp32_ellipse - tgt_ellipse)
abs_qat = np.abs(qat_ellipse - tgt_ellipse)

# Special handling for theta (angle wrapping)
theta_diff_fp32 = np.abs(fp32_ellipse[:, 4] - tgt_ellipse[:, 4])
theta_diff_fp32 = np.minimum(theta_diff_fp32, 180 - theta_diff_fp32)
abs_fp32[:, 4] = theta_diff_fp32

theta_diff_qat = np.abs(qat_ellipse[:, 4] - tgt_ellipse[:, 4])
theta_diff_qat = np.minimum(theta_diff_qat, 180 - theta_diff_qat)
abs_qat[:, 4] = theta_diff_qat

# ============================================================================
# FIXED: Better relative error computation
# ============================================================================
# Use a threshold-based approach to avoid division by near-zero values
EPSILON_THRESHOLD = 0.1  # Minimum denominator for relative error

rel_fp32 = np.zeros_like(abs_fp32)
rel_qat = np.zeros_like(abs_qat)

for i in range(5):
    # Use max of (target value, threshold) as denominator
    denominator = np.maximum(np.abs(tgt_ellipse[:, i]), EPSILON_THRESHOLD)
    rel_fp32[:, i] = (abs_fp32[:, i] / denominator) * 100.0
    rel_qat[:, i] = (abs_qat[:, i] / denominator) * 100.0

# Mean relative errors per parameter
mae_rel_fp32 = rel_fp32.mean(axis=0)
mae_rel_qat = rel_qat.mean(axis=0)

mean_fp32 = mae_rel_fp32.mean()
mean_qat = mae_rel_qat.mean()

# Improvement percentage
improvement_pct = (mae_rel_fp32 - mae_rel_qat) / (mae_rel_fp32 + 1e-12) * 100.0
overall_improv = (mean_fp32 - mean_qat) / (mean_fp32 + 1e-12) * 100.0

# Display results
names = ["cx", "cy", "a", "b", "θ"]

print("=" * 70)
print("RELATIVE ERROR COMPARISON: FP32 vs QAT (Ellipse Parameters)")
print("=" * 70)
print("\nPer-parameter mean relative error (%) — FP32  |  QAT   |  Improvement (%)")
print("-" * 70)

for i, n in enumerate(names):
    print(f"{n:>3}: {mae_rel_fp32[i]:7.3f}% -> {mae_rel_qat[i]:7.3f}%   {improvement_pct[i]:7.2f}%")

print("-" * 70)
print(f"\nOverall mean rel error: FP32 {mean_fp32:.3f}%, QAT {mean_qat:.3f}%  → overall improvement {overall_improv:.2f}%")
print("=" * 70)

# Additional statistics
print("\n" + "=" * 70)
print("ABSOLUTE ERROR STATISTICS (Mean ± Std)")
print("=" * 70)

for i, n in enumerate(names):
    fp32_mean = abs_fp32[:, i].mean()
    fp32_std = abs_fp32[:, i].std()
    qat_mean = abs_qat[:, i].mean()
    qat_std = abs_qat[:, i].std()
    
    print(f"{n:>3}:")
    print(f"  FP32: {fp32_mean:.4f} ± {fp32_std:.4f}")
    print(f"  QAT:  {qat_mean:.4f} ± {qat_std:.4f}")
    print()

# Distribution info for 'b' parameter
print("=" * 70)
print("PARAMETER 'b' DISTRIBUTION (Semi-minor axis)")
print("=" * 70)
print(f"Target 'b' range: [{tgt_ellipse[:, 3].min():.4f}, {tgt_ellipse[:, 3].max():.4f}]")
print(f"Target 'b' mean: {tgt_ellipse[:, 3].mean():.4f}")
print(f"Target 'b' median: {np.median(tgt_ellipse[:, 3]):.4f}")
print(f"Samples with b < {EPSILON_THRESHOLD}: {(tgt_ellipse[:, 3] < EPSILON_THRESHOLD).sum()} / {n_samples}")
# Out:
# Converting covariance parameters to ellipse parameters (a, b, θ)...
#  Conversion complete
#
# ======================================================================
# RELATIVE ERROR COMPARISON: FP32 vs QAT (Ellipse Parameters)
# ======================================================================
#
# Per-parameter mean relative error (%) — FP32  |  QAT   |  Improvement (%)
# ----------------------------------------------------------------------
#  cx:   0.915% ->   1.044%    -14.14%
#  cy:   0.918% ->   1.047%    -14.03%
#   a:   1.600% ->   3.850%   -140.61%
#   b:   5.819% ->  57.357%   -885.66%
#   θ:   0.613% ->   1.669%   -172.31%
# ----------------------------------------------------------------------
#
# Overall mean rel error: FP32 1.973%, QAT 12.993%  → overall improvement -558.59%
# ======================================================================
#
# ======================================================================
# ABSOLUTE ERROR STATISTICS (Mean ± Std)
# ======================================================================
#  cx:
#   FP32: 0.1721 ± 0.1418
#   QAT:  0.1976 ± 0.1595
#
#  cy:
#   FP32: 0.1726 ± 0.1418
#   QAT:  0.1980 ± 0.1598
#
#   a:
#   FP32: 0.2302 ± 0.1894
#   QAT:  0.5315 ± 0.4301
#
#   b:
#   FP32: 0.0697 ± 0.3500
#   QAT:  0.1366 ± 0.5670
#
#   θ:
#   FP32: 0.9236 ± 0.8656
#   QAT:  2.5128 ± 2.3690
#
# ======================================================================
# PARAMETER 'b' DISTRIBUTION (Semi-minor axis)
# ======================================================================
# Target 'b' range: [0.0000, 9.9101]
# Target 'b' mean: 0.2427
# Target 'b' median: 0.0000
# Samples with b < 0.1: 93811 / 100000

# %% [markdown]
#  When b ≈ 0.0001, relative error becomes 0.0696 / 0.0001 * 100 = 69,600%
# Fixed version: Uses max(0.0001, 0.1) = 0.1, so relative error becomes 0.0696 / 0.1 * 100 = 69.6%
#
# The absolute errors show QAT is actually performing well (0.0612 vs 0.0696), but the relative percentage was misleading due to division by near-zero denominators.

# %%
#  Compare FP32 vs QAT Model — MAE and RMSE

import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

DENORM = 400.0  # same normalization factor

def collect_preds(model, loader, name="Model"):
    """Run model on test set and return preds/targets (denormalized)."""
    model.eval()
    preds_all, targs_all = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc=f"Evaluating {name}"):
            images = batch["image"].to(device)
            targets = batch["params"].to(device)
            preds = model(images)
            preds_all.append(preds.cpu())
            targs_all.append(targets.cpu())
    preds_all = torch.cat(preds_all, 0).numpy()
    targs_all = torch.cat(targs_all, 0).numpy()

    # Auto-denormalize if needed
    if np.median(np.abs(preds_all[:, 2:])) <= 5:
        preds_all[:, 2:] *= DENORM
    if np.median(np.abs(targs_all[:, 2:])) <= 5:
        targs_all[:, 2:] *= DENORM
    return preds_all, targs_all


# Get FP32 and QAT predictions
fp32_preds, fp32_targs = collect_preds(model, test_loader, name="FP32 model")
qat_preds, qat_targs   = collect_preds(q_model, test_loader, name="QAT model")

# Compute metrics
def compute_metrics(preds, targs):
    mae = np.mean(np.abs(preds - targs), axis=0)
    rmse = np.sqrt(np.mean((preds - targs)**2, axis=0))
    return mae, rmse

mae_fp32, rmse_fp32 = compute_metrics(fp32_preds, fp32_targs)
mae_qat, rmse_qat = compute_metrics(qat_preds, qat_targs)

names = ["cx", "cy", "lxx", "lxy", "lyy"]

print("\n=== FP32 vs QAT Comparison (MAE & RMSE) ===\n")
print(f"{'Param':<6} {'FP32 MAE':>10} {'QAT MAE':>10} {'FP32 RMSE':>11} {'QAT RMSE':>10}")
print("-" * 60)
for i, name in enumerate(names):
    print(f"{name:<6} {mae_fp32[i]:10.4f} {mae_qat[i]:10.4f} {rmse_fp32[i]:11.4f} {rmse_qat[i]:10.4f}")

print("-" * 60)
print(f"{'Mean':<6} {mae_fp32.mean():10.4f} {mae_qat.mean():10.4f} {rmse_fp32.mean():11.4f} {rmse_qat.mean():10.4f}")

# Optional: bar chart comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
x = np.arange(len(names))
width = 0.35

axes[0].bar(x - width/2, mae_fp32, width, label='FP32', color='steelblue', alpha=0.8)
axes[0].bar(x + width/2, mae_qat, width, label='QAT', color='darkorange', alpha=0.8)
axes[0].set_xlabel('Parameter')
axes[0].set_ylabel('MAE')
axes[0].set_title('Mean Absolute Error: FP32 vs QAT')
axes[0].set_xticks(x)
axes[0].set_xticklabels(names)
axes[0].legend()
axes[0].grid(True, linestyle='--', alpha=0.3)

axes[1].bar(x - width/2, rmse_fp32, width, label='FP32', color='steelblue', alpha=0.8)
axes[1].bar(x + width/2, rmse_qat, width, label='QAT', color='darkorange', alpha=0.8)
axes[1].set_xlabel('Parameter')
axes[1].set_ylabel('RMSE')
axes[1].set_title('Root Mean Squared Error: FP32 vs QAT')
axes[1].set_xticks(x)
axes[1].set_xticklabels(names)
axes[1].legend()
axes[1].grid(True, linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Evaluating FP32 model: 100%|██████████| 1563/1563 [00:02<00:00, 530.90it/s]
# Evaluating QAT model: 100%|██████████| 1563/1563 [00:08<00:00, 187.72it/s]
# === FP32 vs QAT Comparison (MAE & RMSE) ===
#
# Param    FP32 MAE    QAT MAE   FP32 RMSE   QAT RMSE
# ------------------------------------------------------------
# cx        19.9963     0.1976     20.5224     0.2539
# cy        19.9922     0.1980     20.5182     0.2545
# lxx      145.5371    11.6192    157.1797    15.0622
# lxy      129.0178    11.6502    141.9825    14.7341
# lyy       34.6624    17.8093     46.4564    20.2272
# ------------------------------------------------------------
# Mean      69.8411     8.2949     77.3318    10.1064

# %%
# Check Brevitas/PyTorch Compatibility - 

import sys
import torch
import brevitas

print("ENVIRONMENT CHECK")
print(f"Python:   {sys.version}")
print(f"PyTorch:  {torch.__version__}")
print(f"Brevitas: {brevitas.__version__}")
print(f"CUDA:     {torch.version.cuda if torch.cuda.is_available() else 'N/A'}")

# Check for QONNXManager
try:
    from brevitas.export.onnx.qonnx.manager import QONNXManager
    print("\n QONNXManager available")
except ImportError as e:
    print(f"\n QONNXManager NOT available: {e}")
    print("\n Fix: Install compatible versions")
    print("   pip install torch==2.0.1 torchvision==0.15.2")
    print("   pip install brevitas==0.10.0 onnx==1.14.0 qonnx")

# Check for QONNX package 
try:
    import qonnx
    try:
        # Try to get version from package metadata
        from importlib.metadata import version
        qonnx_ver = version('qonnx')
        print(f" QONNX package: {qonnx_ver}")
    except Exception:
        # Fallback: just confirm it's installed
        print(" QONNX package installed")
except ImportError:
    print(" QONNX package missing")
    print("   pip install qonnx")



# Additional checks for export functionality
print("\nExport Function Availability:")
try:
    from brevitas.export import export_qonnx
    print(" export_qonnx() available")
except ImportError:
    print(" export_qonnx() NOT available")

try:
    from brevitas.export.onnx.qonnx.manager import QONNXManager
    print(" QONNXManager.export() available")
except ImportError:
    print(" QONNXManager.export() NOT available")
# Out:
# ENVIRONMENT CHECK
# Python:   3.11.14 | packaged by conda-forge | (main, Oct 22 2025, 22:46:25) [GCC 14.3.0]
# PyTorch:  2.9.0+cu128
# Brevitas: 0.12.1
# CUDA:     12.8
#
#  QONNXManager available
#  QONNX package: 0.4.0
#
# Export Function Availability:
#  export_qonnx() available
#  QONNXManager.export() available
# /home/hritik/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/graph/equalize.py:69: UserWarning: fast_hadamard_transform package not found, using standard pytorch kernels
#   warnings.warn("fast_hadamard_transform package not found, using standard pytorch kernels")

# %%
# OLD CELL - Cell: QAT - FINN Export with Dynamic Batch Size Support + Standard ONNX Export

import torch
import os
import onnx
from onnx import numpy_helper
import numpy as np

os.makedirs("exports", exist_ok=True)

# Load QAT model
q_model = QuantizedEllipseRegressionModel()
q_model.load_state_dict(torch.load("ellipse_qat4_best.pth", map_location='cpu'))
q_model.eval()

print("=" * 70)
print("QAT MODEL EXPORT: QONNX (FINN) + STANDARD ONNX")
print("=" * 70)

dummy_input = torch.randn(1, 1, 20, 20)

# ============================================================================
# PART 1: EXPORT TO QONNX (FINN-COMPATIBLE)
# ============================================================================

# Step 1: Export to Standard ONNX with dynamic batch axis
print("\n[1/6] Exporting to standard ONNX with dynamic batch size")

temp_onnx = "exports/temp_export.onnx"

# CRITICAL: Add dynamic_axes to support variable batch sizes
torch.onnx.export(
    q_model,
    dummy_input,
    temp_onnx,
    export_params=True,
    opset_version=18,
    do_constant_folding=False,  # Preserve quantization params
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={
        'input': {0: 'batch_size'},   #  Make batch dimension dynamic
        'output': {0: 'batch_size'}   #  Make batch dimension dynamic
    },
    verbose=False
)

print(f" Temporary ONNX with dynamic batch: {temp_onnx}")

# Step 2: Load and Add FINN/QONNX Metadata
print("\n[2/6] Adding FINN quantization metadata for QONNX")

model = onnx.load(temp_onnx)

meta_entries = [
    ("producer_name", "brevitas"),
    ("producer_version", "latest"),
    ("quantization_framework", "brevitas"),
    ("quantization_type", "QAT"),
    ("weight_bit_width", "8"),
    ("activation_bit_width", "8"),
    ("weight_quant_type", "INT8"),
    ("activation_quant_type", "INT8"),
    ("model_type", "CNN_regression"),
    ("input_shape", "Nx1x20x20"),  #  Updated to show dynamic batch
    ("output_shape", "Nx5"),       #  Updated to show dynamic batch
]

for key, value in meta_entries:
    meta = model.metadata_props.add()
    meta.key = key
    meta.value = value

print(" Added FINN metadata:")
for key, value in meta_entries:
    print(f"    {key}: {value}")

# Step 3: Extract and Save Quantization Parameters
print("\n[3/6] Extracting quantization parameters")

quant_params = {}

with torch.no_grad():
    # Conv layers
    for i, (name, module) in enumerate([
        ('conv1', q_model.conv1),
        ('conv2', q_model.conv2),
        ('conv3', q_model.conv3),
        ('conv4', q_model.conv4),
    ], 1):
        if hasattr(module, 'quant_weight'):
            try:
                scale = module.quant_weight().scale
                if scale is not None:
                    quant_params[f'{name}_scale'] = float(scale.item() if hasattr(scale, 'item') else scale)
                    print(f"    {name}: scale={quant_params[f'{name}_scale']:.6f}")
            except:
                pass
    
    # FC layers
    for name, module in [('fc1', q_model.fc1), ('fc2', q_model.fc2), ('fc_out', q_model.fc_out)]:
        if hasattr(module, 'quant_weight'):
            try:
                scale = module.quant_weight().scale
                if scale is not None:
                    quant_params[f'{name}_scale'] = float(scale.item() if hasattr(scale, 'item') else scale)
                    print(f"    {name}: scale={quant_params[f'{name}_scale']:.6f}")
            except:
                pass

quant_info_path = "exports/quantization_params.txt"
with open(quant_info_path, 'w') as f:
    f.write("# Brevitas QAT Quantization Parameters\n")
    f.write("# Format: layer_name: scale_value\n\n")
    for key, val in quant_params.items():
        f.write(f"{key}: {val:.8f}\n")

print(f" Quantization params saved: {quant_info_path}")

# Step 4: Save as QONNX-compatible model
print("\n[4/6] Saving QONNX-compatible model (FINN)")

qonnx_path = "exports/ellipse_qat4_model_finn.qonnx"
onnx.save(model, qonnx_path)

print(f" QONNX model saved: {qonnx_path}")
print(f"   Size: {os.path.getsize(qonnx_path)/(1024*1024):.2f} MB")

# ============================================================================
# PART 2: EXPORT TO STANDARD ONNX (QAT MODEL)
# ============================================================================

print("\n[5/6] Exporting QAT model to standard ONNX format")

qat_onnx_path = "exports/ellipse_qat4_model.onnx"

torch.onnx.export(
    q_model,
    dummy_input,
    qat_onnx_path,
    export_params=True,
    opset_version=18,
    do_constant_folding=False,  # Preserve quantization structure
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={
        'input': {0: 'batch_size'},
        'output': {0: 'batch_size'}
    },
    verbose=False
)

print(f" QAT ONNX model saved: {qat_onnx_path}")
print(f"   Size: {os.path.getsize(qat_onnx_path)/(1024*1024):.2f} MB")

# Verify standard ONNX
try:
    qat_onnx_model = onnx.load(qat_onnx_path)
    onnx.checker.check_model(qat_onnx_model)
    print(" Valid standard ONNX model")
except Exception as e:
    print(f"  Standard ONNX verification warning: {e}")

# Clean up temporary file
if os.path.exists(temp_onnx):
    os.remove(temp_onnx)

# ============================================================================
# PART 3: VERIFICATION
# ============================================================================

print("\n[6/6] Verifying exported models")

# Verify QONNX
try:
    onnx.checker.check_model(model)
    print(" Valid QONNX model")
    
    print(f"\n QONNX Model Summary:")
    print(f"    Graph name: {model.graph.name if model.graph.name else 'unnamed'}")
    print(f"    Inputs:  {[i.name for i in model.graph.input]}")
    print(f"    Outputs: {[o.name for o in model.graph.output]}")
    print(f"    Nodes:   {len(model.graph.node)}")
    print(f"    Opset:   {model.opset_import[0].version}")
    
    # Check dynamic axes
    print(f"\n Dynamic Axes:")
    for inp in model.graph.input:
        shape_str = ", ".join([str(d.dim_param if d.dim_param else d.dim_value) for d in inp.type.tensor_type.shape.dim])
        print(f"    {inp.name}: [{shape_str}]")
    
    # Test inference with different batch sizes using ONNX Runtime
    import onnxruntime as ort
    
    try:
        # Test QONNX
        qonnx_sess = ort.InferenceSession(qonnx_path)
        
        # Test batch size 1
        dummy_np_1 = np.random.randn(1, 1, 20, 20).astype(np.float32)
        output_1 = qonnx_sess.run(None, {'input': dummy_np_1})
        print(f"\n QONNX Inference test (batch=1): ")
        print(f"    Output shape: {output_1[0].shape}")
        
        # Test batch size 64
        dummy_np_64 = np.random.randn(64, 1, 20, 20).astype(np.float32)
        output_64 = qonnx_sess.run(None, {'input': dummy_np_64})
        print(f" QONNX Inference test (batch=64): ")
        print(f"    Output shape: {output_64[0].shape}")
        
        # Test standard ONNX
        qat_onnx_sess = ort.InferenceSession(qat_onnx_path)
        output_qat_1 = qat_onnx_sess.run(None, {'input': dummy_np_1})
        print(f"\n QAT ONNX Inference test (batch=1): ")
        print(f"    Output shape: {output_qat_1[0].shape}")
        
        output_qat_64 = qat_onnx_sess.run(None, {'input': dummy_np_64})
        print(f" QAT ONNX Inference test (batch=64): ")
        print(f"    Output shape: {output_qat_64[0].shape}")
        
    except Exception as e:
        print(f"  ONNX Runtime test warning: {e}")
    
    print("\n Export successful with dynamic batch support!")
    
except Exception as e:
    print(f"  Verification warning: {e}")

# ============================================================================
# FINAL SUMMARY
# ============================================================================

print("\n" + "=" * 70)
print("EXPORT COMPLETE - 2 FORMATS READY")
print("=" * 70)

print(f"""
 Exported files:
   • QONNX model (FINN):     {os.path.abspath(qonnx_path)}
   • Standard ONNX (QAT):    {os.path.abspath(qat_onnx_path)}
   • Quantization params:    {os.path.abspath(quant_info_path)}

 Model info:
   • Input:  Nx1x20x20 (batch_size=N, grayscale 20×20 image)
   • Output: Nx5 (cx, cy, lxx, lxy, lyy)
   • Quantization: 8-bit weights + activations (Brevitas QAT)
   • Supports dynamic batch sizes (tested with 1 and 64)

 Use cases:
   • QONNX (.qonnx): For FINN framework & FPGA deployment
   • Standard ONNX (.onnx): For general deployment (TensorRT, mobile, etc.)
""")
# Out:
# ======================================================================
# QAT MODEL EXPORT: QONNX (FINN) + STANDARD ONNX
# ======================================================================
#
# [1/6] Exporting to standard ONNX with dynamic batch size
# /tmp/ipykernel_10956/896235746.py:32: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# Applied 33 of general pattern rewrite rules.
#  Temporary ONNX with dynamic batch: exports/temp_export.onnx
#
# [2/6] Adding FINN quantization metadata for QONNX
#  Added FINN metadata:
#     producer_name: brevitas
#     producer_version: latest
#     quantization_framework: brevitas
#     quantization_type: QAT
#     weight_bit_width: 8
#     activation_bit_width: 8
#     weight_quant_type: INT8
#     activation_quant_type: INT8
#     model_type: CNN_regression
#     input_shape: Nx1x20x20
#     output_shape: Nx5
#
# [3/6] Extracting quantization parameters
#     conv1: scale=0.032560
#     conv2: scale=0.011417
#     conv3: scale=0.010980
#     conv4: scale=0.009773
#     fc1: scale=0.016982
#     fc2: scale=0.011179
#     fc_out: scale=0.016566
#  Quantization params saved: exports/quantization_params.txt
#
# [4/6] Saving QONNX-compatible model (FINN)
#  QONNX model saved: exports/ellipse_qat4_model_finn.qonnx
#    Size: 2.96 MB
#
# [5/6] Exporting QAT model to standard ONNX format
# /tmp/ipykernel_10956/896235746.py:137: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# Applied 33 of general pattern rewrite rules.
#  QAT ONNX model saved: exports/ellipse_qat4_model.onnx
#    Size: 0.47 MB
#  Valid standard ONNX model
#
# [6/6] Verifying exported models
#  Valid QONNX model
#
#  QONNX Model Summary:
#     Graph name: main_graph
#     Inputs:  ['input']
#     Outputs: ['output']
#     Nodes:   180
#     Opset:   18
#
#  Dynamic Axes:
#     input: [s77, 1, 20, 20]
#
#  QONNX Inference test (batch=1):
#     Output shape: (1, 5)
#  QONNX Inference test (batch=64):
#     Output shape: (64, 5)
#
#  QAT ONNX Inference test (batch=1):
#     Output shape: (1, 5)
#  QAT ONNX Inference test (batch=64):
#     Output shape: (64, 5)
#
#  Export successful with dynamic batch support!
#
# ======================================================================
# EXPORT COMPLETE - 2 FORMATS READY
# ======================================================================
#
#  Exported files:
#    • QONNX model (FINN):     /home/hritik/Desktop/Hritik/Project/ellipse-regression-qat32bit/exports/ellipse_qat4_model_finn.qonnx
#    • Standard ONNX (QAT):    /home/hritik/Desktop/Hritik/Project/ellipse-regression-qat32bit/exports/ellipse_qat4_model.onnx
#    • Quantization params:    /home/hritik/Desktop/Hritik/Project/ellipse-regression-qat32bit/exports/quantization_params.txt
#
#  Model info:
#    • Input:  Nx1x20x20 (batch_size=N, grayscale 20×20 image)
#    • Output: Nx5 (cx, cy, lxx, lxy, lyy)
#    • Quantization: 8-bit weights + activations (Brevitas QAT)
#    • Supports dynamic batch sizes (tested with 1 and 64)
#
#  Use cases:
#    • QONNX (.qonnx): For FINN framework & FPGA deployment
#    • Standard ONNX (.onnx): For general deployment (TensorRT, mobile, etc.)
# 2026-02-17 19:23:54.919848320 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:23:54.969789559 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output

# %%
# Cell: QAT Model Export - Brevitas QONNX for FINN

import torch
import os
from brevitas.export import export_qonnx

os.makedirs("exports", exist_ok=True)

# Load QAT model
q_model = QuantizedEllipseRegressionModel()
q_model.load_state_dict(torch.load("ellipse_qat4_best.pth", map_location='cpu'))
q_model.eval()

print("=" * 70)
print("QAT MODEL EXPORT: BREVITAS QONNX (FINN-COMPATIBLE)")
print("=" * 70)

# Create dummy input
dummy_input = torch.randn(1, 1, 20, 20)

# ============================================================================
# EXPORT TO QONNX USING BREVITAS (CORRECT METHOD FOR FINN)
# ============================================================================

qonnx_path = "ellipse_regression_qat4_qonnx.onnx"

print("\n[1/2] Exporting model using Brevitas export_qonnx()...")
print("      This preserves all quantization metadata for FINN")

try:
    export_qonnx(
        q_model,
        input_t=dummy_input,
        export_path=qonnx_path,
        opset_version=13  # FINN prefers opset 13 or lower
    )
    print(f"✅ QONNX export successful: {qonnx_path}")
    
except Exception as e:
    print(f"❌ Brevitas export failed: {e}")
    print("\nTrying alternative export method...")
    
    # Fallback: Manual export with torch.onnx + metadata injection
    import onnx
    
    temp_onnx = "exports/temp_export.onnx"
    torch.onnx.export(
        q_model,
        dummy_input,
        temp_onnx,
        export_params=True,
        opset_version=13,
        do_constant_folding=False,
        input_names=['input'],
        output_names=['output'],
        verbose=False
    )
    
    # Load and add Brevitas metadata
    model = onnx.load(temp_onnx)
    
    meta_entries = [
        ("producer_name", "brevitas"),
        ("producer_version", "0.10.0"),
        ("quantization_framework", "brevitas"),
        ("quantization_type", "QAT"),
        ("weight_bit_width", "8"),
        ("activation_bit_width", "8"),
    ]
    
    for key, value in meta_entries:
        meta = model.metadata_props.add()
        meta.key = key
        meta.value = value
    
    onnx.save(model, qonnx_path)
    os.remove(temp_onnx)
    print(f"✅ Fallback export with metadata: {qonnx_path}")

# ============================================================================
# VERIFICATION
# ============================================================================

print("\n[2/2] Verifying QONNX model...")

import onnx

try:
    model = onnx.load(qonnx_path)
    onnx.checker.check_model(model)
    
    print("✅ Valid QONNX model")
    print(f"   Nodes: {len(model.graph.node)}")
    print(f"   Inputs: {[i.name for i in model.graph.input]}")
    print(f"   Outputs: {[o.name for o in model.graph.output]}")
    print(f"   Opset: {model.opset_import[0].version}")
    print(f"   Size: {os.path.getsize(qonnx_path)/(1024*1024):.2f} MB")
    
    # Check for Brevitas metadata
    print("\n📋 Metadata:")
    for meta in model.metadata_props:
        print(f"   {meta.key}: {meta.value}")
    
except Exception as e:
    print(f"⚠️ Verification warning: {e}")

# ============================================================================
# SUMMARY
# ============================================================================

print("\n" + "=" * 70)
print("EXPORT COMPLETE")
print("=" * 70)
print(f"""
✅ Exported file: {os.path.abspath(qonnx_path)}

📝 Model info:
   • Input:  1×1×20×20 (grayscale 20×20 image)
   • Output: 1×5 (cx, cy, lxx, lxy, lyy)
   • Quantization: 8-bit weights + activations (Brevitas QAT)
   • Format: QONNX (FINN-compatible)

🚀 Next steps:
   1. Run 2-finn-verify-and-export.ipynb to verify numerical accuracy
   2. Apply FINN transformations (Streamline, etc.)
   3. Build hardware with 2-finn.ipynb

⚠️ Important: This file uses Brevitas native export, NOT torch.onnx.export()
   This preserves all quantization metadata required by FINN.
""")
print("=" * 70)
# Out:
# [W217 19:25:19.665336712 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 19:25:19.672338692 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 19:25:19.674258033 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 19:25:19.675453944 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# W0217 19:25:19.111000 10956 site-packages/torch/onnx/_internal/exporter/_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# ======================================================================
# QAT MODEL EXPORT: BREVITAS QONNX (FINN-COMPATIBLE)
# ======================================================================
#
# [1/2] Exporting model using Brevitas export_qonnx()...
#       This preserves all quantization metadata for FINN
# [torch.onnx] Obtain model graph for `QuantizedEllipseRegressionModel([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `QuantizedEllipseRegressionModel([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# W0217 19:25:19.675000 10956 site-packages/torch/onnx/_internal/exporter/_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ❌
# ❌ Brevitas export failed: Failed to convert the exported program to an ONNX model. This is step 3/3 of exporting the model to ONNX. Next steps:
# - If there is a missing ONNX function, implement it and register it to the registry.
# - If there is an internal error during ONNX conversion, debug the error and summit a PR to PyTorch.
# - Create an error report with `torch.onnx.export(..., report=True)`, and save the ExportedProgram as a pt2 file. Create an issue in the PyTorch GitHub repository against the *onnx* component. Attach the error report and the pt2 model.
#
# ## Exception summary
#
# <class 'torch.onnx._internal.exporter._errors.DispatchError'>: No ONNX function found for <OpOverload(op='qonnx.int_quant', overload='default')>. Failure message: No decompositions registered for the real-valued input
# ⬆️
# <class 'torch.onnx._internal.exporter._errors.ConversionError'>: Error when translating node %int_quant : [num_users=1] = call_function[target=torch.ops.qonnx.int_quant.default](args = (%slice_1, %c_conv1_weight_quant_export_handler_lifted_tensor_0, %c_conv1_weight_quant_export_handler_lifted_tensor_1, %c_conv1_weight_quant_export_handler_lifted_tensor_2, 1, 1, ROUND), kwargs = {}). See the stack trace for more information.
#
# (Refer to the full stack trace above for more information.)
#
# Trying alternative export method...
# ---------------------------------------------------------------------------
# DispatchError                             Traceback (most recent call last)
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:796, in _translate_fx_graph(fx_graph, model, graph_like, owned_graphs, lower, registry)
#     795 if lower == "at_conversion":
# --> 796     _handle_call_function_node_with_lowering(
#     797         model,
#     798         node,
#     799         node_name_to_values,
#     800         graph_like=graph_like,
#     801         constant_farm=constant_farm,
#     802         registry=registry,
#     803         opset=opset,
#     804         node_name_to_local_functions=node_name_to_local_functions,
#     805     )
#     806 else:
#     807     # No lowering
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:581, in _handle_call_function_node_with_lowering(model, node, node_name_to_values, graph_like, constant_farm, registry, opset, node_name_to_local_functions)
#     580 if onnx_function is None:
# --> 581     raise _errors.DispatchError(
#     582         f"No ONNX function found for {node.target!r}. Failure message: {message}"
#     583     )
#     585 with onnxscript.evaluator.default_as(
#     586     tracer := _building.OpRecorder(opset, constant_farm)
#     587 ):
#
# DispatchError: No ONNX function found for <OpOverload(op='qonnx.int_quant', overload='default')>. Failure message: No decompositions registered for the real-valued input
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1465, in export(model, args, kwargs, registry, dynamic_shapes, input_names, output_names, report, verify, profile, dump_exported_program, artifacts_dir, verbose)
#    1463 try:
#    1464     # Convert the exported program to an ONNX model
# -> 1465     onnx_program = _exported_program_to_onnx_program(
#    1466         decomposed_program, registry=registry
#    1467     )
#    1468     # Record the strategy used for getting the exported program for unit test assertions
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1096, in _exported_program_to_onnx_program(exported_program, registry, lower)
#    1094         graph_like = func
# -> 1096     values = _translate_fx_graph(
#    1097         fx_graph,
#    1098         model,
#    1099         graph_like=graph_like,
#    1100         owned_graphs=owned_graphs,
#    1101         lower=lower,
#    1102         registry=registry,
#    1103     )
#    1105 assert name == "", "The last module processed should be the root module"
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:822, in _translate_fx_graph(fx_graph, model, graph_like, owned_graphs, lower, registry)
#     821     except Exception as e:
# --> 822         raise _errors.ConversionError(
#     823             f"Error when translating node {node.format_node()}. See the stack trace for more information."
#     824         ) from e
#     825 return node_name_to_values
#
# ConversionError: Error when translating node %int_quant : [num_users=1] = call_function[target=torch.ops.qonnx.int_quant.default](args = (%slice_1, %c_conv1_weight_quant_export_handler_lifted_tensor_0, %c_conv1_weight_quant_export_handler_lifted_tensor_1, %c_conv1_weight_quant_export_handler_lifted_tensor_2, 1, 1, ROUND), kwargs = {}). See the stack trace for more information.
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[26], line 31
#      30 try:
# ---> 31     export_qonnx(
#      32         q_model,
#      33         input_t=dummy_input,
#      34         export_path=qonnx_path,
#      35         opset_version=13  # FINN prefers opset 13 or lower
#      36     )
#      37     print(f"✅ QONNX export successful: {qonnx_path}")
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/export/__init__.py:31, in export_qonnx(*args, **kwargs)
#      30     return _export_qonnx_dynamo(*args, **kwargs)
# ---> 31 return _export_qonnx_torchscript(*args, **kwargs)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/export/__init__.py:22, in export_qonnx.<locals>._export_qonnx_torchscript(*args, **kwargs)
#      20 @wraps(QONNXManager.export)
#      21 def _export_qonnx_torchscript(*args, **kwargs):
# ---> 22     return QONNXManager.export(*args, **kwargs)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/export/onnx/manager.py:215, in ONNXBaseManager.export(cls, module, args, export_path, input_shape, input_t, disable_warnings, **onnx_export_kwargs)
#     204 @classmethod
#     205 def export(
#     206         cls,
#    (...)    213         disable_warnings=True,
#     214         **onnx_export_kwargs):
# --> 215     return cls.export_onnx(
#     216         module, args, export_path, input_shape, input_t, disable_warnings, **onnx_export_kwargs)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/export/onnx/qonnx/manager.py:107, in QONNXManager.export_onnx(cls, module, args, export_path, input_shape, input_t, disable_warnings, **onnx_export_kwargs)
#     106     onnx_export_kwargs[key] = {QONNX_DOMAIN_STRING: QONNX_DOMAIN_VERSION}
# --> 107 return super(QONNXManager, cls).export_onnx(
#     108     module, args, export_path, input_shape, input_t, disable_warnings, **onnx_export_kwargs)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/brevitas/export/onnx/manager.py:185, in ONNXBaseManager.export_onnx(cls, module, args, export_path, input_shape, input_t, disable_warnings, **onnx_export_kwargs)
#     184 with patch_export():
# --> 185     torch.onnx.export(module, args, export_target, **onnx_export_kwargs)
#     187 # restore the model to previous properties
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/__init__.py:296, in export(model, args, f, kwargs, verbose, input_names, output_names, opset_version, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, export_params, keep_initializers_as_inputs, dynamic_axes, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining)
#     287     legacy_export_kwargs = {
#     288         "training": training,
#     289         "operator_export_type": operator_export_type,
#    (...)    293         "autograd_inlining": autograd_inlining,
#     294     }
# --> 296     return _compat.export_compat(
#     297         model,
#     298         args,
#     299         f,
#     300         kwargs=kwargs,
#     301         export_params=export_params,
#     302         verbose=verbose,
#     303         input_names=input_names,
#     304         output_names=output_names,
#     305         opset_version=opset_version,
#     306         custom_translation_table=custom_translation_table,
#     307         dynamic_axes=dynamic_axes,
#     308         keep_initializers_as_inputs=keep_initializers_as_inputs,
#     309         external_data=external_data,
#     310         dynamic_shapes=dynamic_shapes,
#     311         report=report,
#     312         optimize=optimize,
#     313         verify=verify,
#     314         profile=profile,
#     315         dump_exported_program=dump_exported_program,
#     316         artifacts_dir=artifacts_dir,
#     317         fallback=fallback,
#     318         legacy_export_kwargs=legacy_export_kwargs,
#     319     )
#     320 else:
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_compat.py:143, in export_compat(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, custom_translation_table, dynamic_axes, dynamic_shapes, keep_initializers_as_inputs, external_data, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, legacy_export_kwargs)
#     142 try:
# --> 143     onnx_program = _core.export(
#     144         model,
#     145         args,
#     146         kwargs,
#     147         registry=registry,
#     148         dynamic_shapes=dynamic_shapes_with_export_dim,
#     149         input_names=input_names,
#     150         output_names=output_names,
#     151         profile=profile,
#     152         report=report,
#     153         verify=verify,
#     154         dump_exported_program=dump_exported_program,
#     155         artifacts_dir=artifacts_dir,
#     156         verbose=verbose,
#     157     )
#     159 except Exception as e:
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_flags.py:23, in set_onnx_exporting_flag.<locals>.wrapper(*args, **kwargs)
#      22 try:
# ---> 23     return func(*args, **kwargs)
#      24 finally:
#      25     # Ensure it resets even if an exception occurs
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1511, in export(model, args, kwargs, registry, dynamic_shapes, input_names, output_names, report, verify, profile, dump_exported_program, artifacts_dir, verbose)
#    1509         report_path = None
# -> 1511     raise _errors.ConversionError(
#    1512         _STEP_THREE_ERROR_MESSAGE
#    1513         + (f"\nError report has been saved to '{report_path}'." if report else "")
#    1514         + _summarize_exception_stack(e)
#    1515     ) from e
#    1517 profile_result = _maybe_stop_profiler_and_get_result(profiler)
#
# ConversionError: Failed to convert the exported program to an ONNX model. This is step 3/3 of exporting the model to ONNX. Next steps:
# - If there is a missing ONNX function, implement it and register it to the registry.
# - If there is an internal error during ONNX conversion, debug the error and summit a PR to PyTorch.
# - Create an error report with `torch.onnx.export(..., report=True)`, and save the ExportedProgram as a pt2 file. Create an issue in the PyTorch GitHub repository against the *onnx* component. Attach the error report and the pt2 model.
#
# ## Exception summary
#
# <class 'torch.onnx._internal.exporter._errors.DispatchError'>: No ONNX function found for <OpOverload(op='qonnx.int_quant', overload='default')>. Failure message: No decompositions registered for the real-valued input
# ⬆️
# <class 'torch.onnx._internal.exporter._errors.ConversionError'>: Error when translating node %int_quant : [num_users=1] = call_function[target=torch.ops.qonnx.int_quant.default](args = (%slice_1, %c_conv1_weight_quant_export_handler_lifted_tensor_0, %c_conv1_weight_quant_export_handler_lifted_tensor_1, %c_conv1_weight_quant_export_handler_lifted_tensor_2, 1, 1, ROUND), kwargs = {}). See the stack trace for more information.
#
# (Refer to the full stack trace above for more information.)
#
# During handling of the above exception, another exception occurred:
#
# DispatchError                             Traceback (most recent call last)
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:796, in _translate_fx_graph(fx_graph, model, graph_like, owned_graphs, lower, registry)
#     795 if lower == "at_conversion":
# --> 796     _handle_call_function_node_with_lowering(
#     797         model,
#     798         node,
#     799         node_name_to_values,
#     800         graph_like=graph_like,
#     801         constant_farm=constant_farm,
#     802         registry=registry,
#     803         opset=opset,
#     804         node_name_to_local_functions=node_name_to_local_functions,
#     805     )
#     806 else:
#     807     # No lowering
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:581, in _handle_call_function_node_with_lowering(model, node, node_name_to_values, graph_like, constant_farm, registry, opset, node_name_to_local_functions)
#     580 if onnx_function is None:
# --> 581     raise _errors.DispatchError(
#     582         f"No ONNX function found for {node.target!r}. Failure message: {message}"
#     583     )
#     585 with onnxscript.evaluator.default_as(
#     586     tracer := _building.OpRecorder(opset, constant_farm)
#     587 ):
#
# DispatchError: No ONNX function found for <OpOverload(op='qonnx.int_quant', overload='default')>. Failure message: No decompositions registered for the real-valued input
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1465, in export(model, args, kwargs, registry, dynamic_shapes, input_names, output_names, report, verify, profile, dump_exported_program, artifacts_dir, verbose)
#    1463 try:
#    1464     # Convert the exported program to an ONNX model
# -> 1465     onnx_program = _exported_program_to_onnx_program(
#    1466         decomposed_program, registry=registry
#    1467     )
#    1468     # Record the strategy used for getting the exported program for unit test assertions
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1096, in _exported_program_to_onnx_program(exported_program, registry, lower)
#    1094         graph_like = func
# -> 1096     values = _translate_fx_graph(
#    1097         fx_graph,
#    1098         model,
#    1099         graph_like=graph_like,
#    1100         owned_graphs=owned_graphs,
#    1101         lower=lower,
#    1102         registry=registry,
#    1103     )
#    1105 assert name == "", "The last module processed should be the root module"
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:822, in _translate_fx_graph(fx_graph, model, graph_like, owned_graphs, lower, registry)
#     821     except Exception as e:
# --> 822         raise _errors.ConversionError(
#     823             f"Error when translating node {node.format_node()}. See the stack trace for more information."
#     824         ) from e
#     825 return node_name_to_values
#
# ConversionError: Error when translating node %int_quant : [num_users=1] = call_function[target=torch.ops.qonnx.int_quant.default](args = (%slice_1, %c_conv1_weight_quant_export_handler_lifted_tensor_0, %c_conv1_weight_quant_export_handler_lifted_tensor_1, %c_conv1_weight_quant_export_handler_lifted_tensor_2, 1, 1, ROUND), kwargs = {}). See the stack trace for more information.
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[26], line 47
#      44 import onnx
#      46 temp_onnx = "exports/temp_export.onnx"
# ---> 47 torch.onnx.export(
#      48     q_model,
#      49     dummy_input,
#      50     temp_onnx,
#      51     export_params=True,
#      52     opset_version=13,
#      53     do_constant_folding=False,
#      54     input_names=['input'],
#      55     output_names=['output'],
#      56     verbose=False
#      57 )
#      59 # Load and add Brevitas metadata
#      60 model = onnx.load(temp_onnx)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/__init__.py:296, in export(model, args, f, kwargs, verbose, input_names, output_names, opset_version, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, export_params, keep_initializers_as_inputs, dynamic_axes, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining)
#     286     # Prepare legacy export parameters for potential fallback
#     287     legacy_export_kwargs = {
#     288         "training": training,
#     289         "operator_export_type": operator_export_type,
#    (...)    293         "autograd_inlining": autograd_inlining,
#     294     }
# --> 296     return _compat.export_compat(
#     297         model,
#     298         args,
#     299         f,
#     300         kwargs=kwargs,
#     301         export_params=export_params,
#     302         verbose=verbose,
#     303         input_names=input_names,
#     304         output_names=output_names,
#     305         opset_version=opset_version,
#     306         custom_translation_table=custom_translation_table,
#     307         dynamic_axes=dynamic_axes,
#     308         keep_initializers_as_inputs=keep_initializers_as_inputs,
#     309         external_data=external_data,
#     310         dynamic_shapes=dynamic_shapes,
#     311         report=report,
#     312         optimize=optimize,
#     313         verify=verify,
#     314         profile=profile,
#     315         dump_exported_program=dump_exported_program,
#     316         artifacts_dir=artifacts_dir,
#     317         fallback=fallback,
#     318         legacy_export_kwargs=legacy_export_kwargs,
#     319     )
#     320 else:
#     321     import warnings
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_compat.py:143, in export_compat(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, custom_translation_table, dynamic_axes, dynamic_shapes, keep_initializers_as_inputs, external_data, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, legacy_export_kwargs)
#     141             registry.register_op(torch_op, op, is_complex=False)
#     142 try:
# --> 143     onnx_program = _core.export(
#     144         model,
#     145         args,
#     146         kwargs,
#     147         registry=registry,
#     148         dynamic_shapes=dynamic_shapes_with_export_dim,
#     149         input_names=input_names,
#     150         output_names=output_names,
#     151         profile=profile,
#     152         report=report,
#     153         verify=verify,
#     154         dump_exported_program=dump_exported_program,
#     155         artifacts_dir=artifacts_dir,
#     156         verbose=verbose,
#     157     )
#     159 except Exception as e:
#     160     if fallback:
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_flags.py:23, in set_onnx_exporting_flag.<locals>.wrapper(*args, **kwargs)
#      21 _is_onnx_exporting = True
#      22 try:
# ---> 23     return func(*args, **kwargs)
#      24 finally:
#      25     # Ensure it resets even if an exception occurs
#      26     _is_onnx_exporting = False
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/torch/onnx/_internal/exporter/_core.py:1511, in export(model, args, kwargs, registry, dynamic_shapes, input_names, output_names, report, verify, profile, dump_exported_program, artifacts_dir, verbose)
#    1508     else:
#    1509         report_path = None
# -> 1511     raise _errors.ConversionError(
#    1512         _STEP_THREE_ERROR_MESSAGE
#    1513         + (f"\nError report has been saved to '{report_path}'." if report else "")
#    1514         + _summarize_exception_stack(e)
#    1515     ) from e
#    1517 profile_result = _maybe_stop_profiler_and_get_result(profiler)
#    1519 assert onnx_program.exported_program is not None
#
# ConversionError: Failed to convert the exported program to an ONNX model. This is step 3/3 of exporting the model to ONNX. Next steps:
# - If there is a missing ONNX function, implement it and register it to the registry.
# - If there is an internal error during ONNX conversion, debug the error and summit a PR to PyTorch.
# - Create an error report with `torch.onnx.export(..., report=True)`, and save the ExportedProgram as a pt2 file. Create an issue in the PyTorch GitHub repository against the *onnx* component. Attach the error report and the pt2 model.
#
# ## Exception summary
#
# <class 'torch.onnx._internal.exporter._errors.DispatchError'>: No ONNX function found for <OpOverload(op='qonnx.int_quant', overload='default')>. Failure message: No decompositions registered for the real-valued input
# ⬆️
# <class 'torch.onnx._internal.exporter._errors.ConversionError'>: Error when translating node %int_quant : [num_users=1] = call_function[target=torch.ops.qonnx.int_quant.default](args = (%slice_1, %c_conv1_weight_quant_export_handler_lifted_tensor_0, %c_conv1_weight_quant_export_handler_lifted_tensor_1, %c_conv1_weight_quant_export_handler_lifted_tensor_2, 1, 1, ROUND), kwargs = {}). See the stack trace for more information.
#
# (Refer to the full stack trace above for more information.)

# %%
# Cell: QAT-4 Export - Brevitas QONNX for FINN (FORCE TORCHSCRIPT)

import os
import torch
from brevitas.export import export_qonnx

os.makedirs("exports", exist_ok=True)

# Load QAT-4 model
q_model = QuantizedEllipseRegressionModel()
q_model.load_state_dict(torch.load("ellipse_qat4_best.pth", map_location="cpu"))
q_model.eval()

print("=" * 70)
print("EXPORT: BREVITAS -> QONNX (FINN-COMPATIBLE)")
print("=" * 70)

# 🔑 KEY FIX: Force TorchScript export path (disable dynamo)
os.environ["BREVITAS_IGNORE_MISSING_KEYS"] = "1"

# IMPORTANT: use the exact input shape your model expects
dummy_input = torch.randn(1, 1, 20, 20)

qonnx_path = "ellipse_regression_qat4_qonnx.onnx"

# Export with explicit dynamo=False parameter
try:
    export_qonnx(
        q_model,
        input_t=dummy_input,
        export_path=qonnx_path,
        opset_version=13,
        dynamo=False  # ← Force TorchScript path
    )
    print(f"✅ QONNX export successful: {qonnx_path}")
except TypeError:
    # Fallback if dynamo parameter doesn't exist in your Brevitas version
    print("⚠️ 'dynamo' parameter not supported, using alternative method...")
    
    # Alternative: Use QONNXManager directly
    from brevitas.export.onnx.qonnx.manager import QONNXManager
    
    QONNXManager.export(
        q_model,
        input_t=dummy_input,
        export_path=qonnx_path,
        opset_version=13
    )
    print(f"✅ QONNX export successful (QONNXManager): {qonnx_path}")

print(f"   Size: {os.path.getsize(qonnx_path)/(1024*1024):.2f} MB")

# Basic ONNX load check
import onnx
m = onnx.load(qonnx_path)
onnx.checker.check_model(m)

print(f"✅ ONNX checker passed")
print(f"   Nodes: {len(m.graph.node)}")
print(f"   Inputs: {[i.name for i in m.graph.input]}")
print(f"   Outputs: {[o.name for o in m.graph.output]}")
print(f"   Opset: {m.opset_import[0].version}")
# Out:
# ======================================================================
# EXPORT: BREVITAS -> QONNX (FINN-COMPATIBLE)
# ======================================================================
# ✅ QONNX export successful: ellipse_regression_qat4_qonnx.onnx
#    Size: 2.50 MB
# ✅ ONNX checker passed
#    Nodes: 38
#    Inputs: ['quant_input.1', 'conv1.weight', 'bn1.weight', 'bn1.bias', 'bn1.running_mean', 'bn1.running_var', 'conv2.weight', 'bn2.weight', 'bn2.bias', 'bn2.running_mean', 'bn2.running_var', 'conv3.weight', 'bn3.weight', 'bn3.bias', 'bn3.running_mean', 'bn3.running_var', 'conv4.weight', 'bn4.weight', 'bn4.bias', 'bn4.running_mean', 'bn4.running_var', 'fc1.weight', 'fc2.weight', 'fc_out.weight']
#    Outputs: ['83']
#    Opset: 13
# [W217 23:08:08.174680962 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.175686133 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.176703166 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.178048630 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.210710081 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.216531666 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.222119497 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W217 23:08:08.227922056 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
# Measure Inference Time: FP32 vs QAT

import torch
import time
import numpy as np
from tqdm import tqdm

device = globals().get('device', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# Load models
fp32_model = EllipseRegressionModel().to(device)
fp32_model.load_state_dict(torch.load("ellipse_fp32_best.pth", map_location=device))
fp32_model.eval()

q_model = QuantizedEllipseRegressionModel().to(device)
q_model.load_state_dict(torch.load("ellipse_qat4_best.pth", map_location=device))
q_model.eval()

print(f"Running inference time benchmarks on: {device}\n")

# Warmup (important for GPU timing accuracy)
print("Warming up models...")
dummy = torch.randn(1, 1, 20, 20).to(device)
with torch.no_grad():
    for _ in range(10):
        _ = fp32_model(dummy)
        _ = q_model(dummy)
if device.type == 'cuda':
    torch.cuda.synchronize()

# Benchmark function
def measure_inference_time(model, loader, model_name="Model", num_iterations=None):
    """Measure average inference time per batch and per sample."""
    model.eval()
    
    times_per_batch = []
    total_samples = 0
    
    with torch.no_grad():
        iterator = tqdm(loader, desc=f"Benchmarking {model_name}")
        for i, batch in enumerate(iterator):
            if num_iterations is not None and i >= num_iterations:
                break
                
            images = batch["image"].to(device)
            batch_size = images.size(0)
            
            # Start timing
            if device.type == 'cuda':
                torch.cuda.synchronize()
            start_time = time.perf_counter()
            
            # Inference
            _ = model(images)
            
            # End timing
            if device.type == 'cuda':
                torch.cuda.synchronize()
            end_time = time.perf_counter()
            
            elapsed = (end_time - start_time) * 1000  # convert to ms
            times_per_batch.append(elapsed)
            total_samples += batch_size
    
    times_per_batch = np.array(times_per_batch)
    
    # Compute statistics
    mean_time_batch = times_per_batch.mean()
    std_time_batch = times_per_batch.std()
    median_time_batch = np.median(times_per_batch)
    
    # Per-sample timing (approximate, assuming uniform batch sizes)
    avg_batch_size = total_samples / len(times_per_batch)
    mean_time_sample = mean_time_batch / avg_batch_size
    
    return {
        'mean_batch_ms': mean_time_batch,
        'std_batch_ms': std_time_batch,
        'median_batch_ms': median_time_batch,
        'mean_sample_ms': mean_time_sample,
        'total_samples': total_samples,
        'num_batches': len(times_per_batch)
    }

# Run benchmarks on test set
print("\n" + "="*60)
print("FP32 MODEL INFERENCE TIME")
print("="*60)
fp32_stats = measure_inference_time(fp32_model, test_loader, model_name="FP32")

print(f"\nResults ({fp32_stats['num_batches']} batches, {fp32_stats['total_samples']} samples):")
print(f"  Mean time per batch:   {fp32_stats['mean_batch_ms']:.3f} ± {fp32_stats['std_batch_ms']:.3f} ms")
print(f"  Median time per batch: {fp32_stats['median_batch_ms']:.3f} ms")
print(f"  Mean time per sample:  {fp32_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:            {1000.0 / fp32_stats['mean_sample_ms']:.1f} samples/sec")

print("\n" + "="*60)
print("QAT MODEL INFERENCE TIME")
print("="*60)
qat_stats = measure_inference_time(q_model, test_loader, model_name="QAT")

print(f"\nResults ({qat_stats['num_batches']} batches, {qat_stats['total_samples']} samples):")
print(f"  Mean time per batch:   {qat_stats['mean_batch_ms']:.3f} ± {qat_stats['std_batch_ms']:.3f} ms")
print(f"  Median time per batch: {qat_stats['median_batch_ms']:.3f} ms")
print(f"  Mean time per sample:  {qat_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:            {1000.0 / qat_stats['mean_sample_ms']:.1f} samples/sec")

# Comparison
print("\n" + "="*60)
print("COMPARISON: FP32 vs QAT")
print("="*60)

speedup = fp32_stats['mean_sample_ms'] / qat_stats['mean_sample_ms']
if speedup > 1:
    print(f"QAT is {speedup:.2f}x FASTER than FP32")
else:
    print(f"QAT is {1/speedup:.2f}x SLOWER than FP32")

print(f"\nPer-sample inference time:")
print(f"  FP32: {fp32_stats['mean_sample_ms']:.4f} ms")
print(f"  QAT:  {qat_stats['mean_sample_ms']:.4f} ms")
print(f"  Difference: {abs(fp32_stats['mean_sample_ms'] - qat_stats['mean_sample_ms']):.4f} ms")

print(f"\nThroughput (samples/sec):")
print(f"  FP32: {1000.0 / fp32_stats['mean_sample_ms']:.1f}")
print(f"  QAT:  {1000.0 / qat_stats['mean_sample_ms']:.1f}")

# Note about quantization benefits
#print("\n" + "="*60)
#print("NOTE:")
#print("="*60)
#print("QAT models show speed benefits primarily when:")
#print("  • Deployed on edge devices (mobile, embedded)")
#print("  • Using quantized inference engines (TensorRT, ONNX Runtime with INT8)")
#print("  • Converted to true INT8 format (not simulated quantization)")
#print(f"\nCurrent test uses: {device}")
#if device.type == 'cpu':
#    print("  → FP32 and QAT have similar speeds on CPU without INT8 backend")
#else:
#    print("  → GPU may not show full QAT benefits without INT8 kernels")
# Out:
# Running inference time benchmarks on: cuda
#
# Warming up models...
#
# ============================================================
# FP32 MODEL INFERENCE TIME
# ============================================================
# Benchmarking FP32: 100%|██████████| 1563/1563 [00:02<00:00, 523.23it/s]
# Results (1563 batches, 100000 samples):
#   Mean time per batch:   0.473 ± 0.172 ms
#   Median time per batch: 0.433 ms
#   Mean time per sample:  0.0074 ms
#   Throughput:            135144.4 samples/sec
#
# ============================================================
# QAT MODEL INFERENCE TIME
# ============================================================
# Benchmarking QAT: 100%|██████████| 1563/1563 [00:08<00:00, 190.30it/s]
# Results (1563 batches, 100000 samples):
#   Mean time per batch:   4.988 ± 0.476 ms
#   Median time per batch: 4.897 ms
#   Mean time per sample:  0.0780 ms
#   Throughput:            12827.4 samples/sec
#
# ============================================================
# COMPARISON: FP32 vs QAT
# ============================================================
# QAT is 10.54x SLOWER than FP32
#
# Per-sample inference time:
#   FP32: 0.0074 ms
#   QAT:  0.0780 ms
#   Difference: 0.0706 ms
#
# Throughput (samples/sec):
#   FP32: 135144.4
#   QAT:  12827.4

# %%
# Export FP32 Model to Standard ONNX (with dynamic batch)

import torch
import onnx
import os

os.makedirs("exports", exist_ok=True)

print("="*70)
print("EXPORTING FP32 MODEL TO ONNX (DYNAMIC BATCH)")
print("="*70)

fp32_model = EllipseRegressionModel().to('cpu')
fp32_model.load_state_dict(torch.load("ellipse_fp32_best.pth", map_location='cpu'))
fp32_model.eval()

dummy_input = torch.randn(1, 1, 20, 20)
fp32_onnx_path = "exports/ellipse_fp32_model.onnx"

torch.onnx.export(
    fp32_model,
    dummy_input,
    fp32_onnx_path,
    export_params=True,
    opset_version=18,
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={
        'input': {0: 'batch_size'},   #  Dynamic batch
        'output': {0: 'batch_size'}
    },
    verbose=False
)

print(f" FP32 ONNX model saved: {fp32_onnx_path}")
print(f"  Size: {os.path.getsize(fp32_onnx_path)/(1024*1024):.2f} MB")

model_onnx = onnx.load(fp32_onnx_path)
onnx.checker.check_model(model_onnx)
print(" Valid ONNX model with dynamic batch support")
# Out:
# ======================================================================
# EXPORTING FP32 MODEL TO ONNX (DYNAMIC BATCH)
# ======================================================================
# /tmp/ipykernel_10956/1119033254.py:20: UserWarning: # 'dynamic_axes' is not recommended when dynamo=True, and may lead to 'torch._dynamo.exc.UserError: Constraints violated.' Supply the 'dynamic_shapes' argument instead if export is unsuccessful.
#   torch.onnx.export(
# Applied 5 of general pattern rewrite rules.
#  FP32 ONNX model saved: exports/ellipse_fp32_model.onnx
#   Size: 0.02 MB
#  Valid ONNX model with dynamic batch support

# %%
# Compare Inference Speed: FP32 ONNX vs QONNX (Using ONNX Runtime + QONNX Execution)

import onnxruntime as ort
import numpy as np
import time
from tqdm import tqdm

# Import QONNX for handling Brevitas quantization ops
from qonnx.core.modelwrapper import ModelWrapper
from qonnx.core.onnx_exec import execute_onnx
from qonnx.transformation.infer_shapes import InferShapes

print("="*70)
print("INFERENCE SPEED COMPARISON: FP32 ONNX vs QONNX")
print("="*70)

# Paths
fp32_onnx_path = "exports/ellipse_fp32_model.onnx"
qonnx_path = "ellipse_regression_qonnx.onnx"

# Session options for FP32 (optimization level)
sess_options = ort.SessionOptions()
sess_options.graph_optimization_level = ort.GraphOptimizationLevel.ORT_ENABLE_ALL

# Select execution provider
device = globals().get('device', torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
providers = ['CUDAExecutionProvider', 'CPUExecutionProvider'] if device.type == 'cuda' else ['CPUExecutionProvider']

#  Load FP32 ONNX Model (Standard ONNX Runtime)
print("\n[1/2] Loading FP32 ONNX model (ONNX Runtime)...")
try:
    fp32_session = ort.InferenceSession(fp32_onnx_path, sess_options, providers=providers)
    print(f"✓ FP32 ONNX loaded with providers: {fp32_session.get_providers()}")
except Exception as e:
    print(f"✗ Failed to load FP32 ONNX: {e}")
    raise

#  Load QONNX Model (QONNX Execution Context)
print("\n[2/2] Loading QONNX model (QONNX Execution Context)...")
try:
    qonnx_model = ModelWrapper(qonnx_path)
    
    # Infer shapes (required for QONNX execution)
    print("  Inferring tensor shapes...")
    qonnx_model = qonnx_model.transform(InferShapes())
    
    print(f"✓ QONNX model loaded successfully")
    print(f"  Input name: {qonnx_model.graph.input[0].name}")
    print(f"  Output name: {qonnx_model.graph.output[0].name}")
except Exception as e:
    print(f"✗ Failed to load QONNX: {e}")
    raise

#  Warmup 
print("\nWarming up both models...")
dummy_np = np.random.randn(1, 1, 20, 20).astype(np.float32)

# Warmup FP32
for _ in range(10):
    _ = fp32_session.run(None, {'input': dummy_np})

# Warmup QONNX (uses execute_onnx)
input_name = qonnx_model.graph.input[0].name
for _ in range(10):
    input_dict = {input_name: dummy_np}
    _ = execute_onnx(qonnx_model, input_dict, return_full_exec_context=False)

print("✓ Warmup complete\n")

#  Benchmark Function for ONNX Runtime
def benchmark_onnx_session(session, loader, model_name="Model"):
    """Measure ONNX Runtime inference time."""
    times_per_batch = []
    total_samples = 0
    
    for batch in tqdm(loader, desc=f"Benchmarking {model_name}"):
        images_np = batch["image"].numpy().astype(np.float32)
        batch_size = images_np.shape[0]
        
        start = time.perf_counter()
        _ = session.run(None, {'input': images_np})
        end = time.perf_counter()
        
        elapsed_ms = (end - start) * 1000
        times_per_batch.append(elapsed_ms)
        total_samples += batch_size
    
    times = np.array(times_per_batch)
    avg_batch_size = total_samples / len(times)
    
    return {
        'mean_batch_ms': times.mean(),
        'std_batch_ms': times.std(),
        'median_batch_ms': np.median(times),
        'mean_sample_ms': times.mean() / avg_batch_size,
        'total_samples': total_samples,
        'num_batches': len(times)
    }

#  Benchmark Function for QONNX Execution
def benchmark_qonnx_model(model, loader, model_name="QONNX"):
    """Measure QONNX execution time."""
    input_name = model.graph.input[0].name
    times_per_batch = []
    total_samples = 0
    
    for batch in tqdm(loader, desc=f"Benchmarking {model_name}"):
        images_np = batch["image"].numpy().astype(np.float32)
        batch_size = images_np.shape[0]
        
        start = time.perf_counter()
        input_dict = {input_name: images_np}
        _ = execute_onnx(model, input_dict, return_full_exec_context=False)
        end = time.perf_counter()
        
        elapsed_ms = (end - start) * 1000
        times_per_batch.append(elapsed_ms)
        total_samples += batch_size
    
    times = np.array(times_per_batch)
    avg_batch_size = total_samples / len(times)
    
    return {
        'mean_batch_ms': times.mean(),
        'std_batch_ms': times.std(),
        'median_batch_ms': np.median(times),
        'mean_sample_ms': times.mean() / avg_batch_size,
        'total_samples': total_samples,
        'num_batches': len(times)
    }

#  Benchmark FP32 ONNX 
print("="*70)
print("FP32 ONNX MODEL (ONNX Runtime)")
print("="*70)
fp32_onnx_stats = benchmark_onnx_session(fp32_session, test_loader, "FP32 ONNX")

print(f"\nResults ({fp32_onnx_stats['num_batches']} batches, {fp32_onnx_stats['total_samples']} samples):")
print(f"  Mean per batch:   {fp32_onnx_stats['mean_batch_ms']:.3f} ± {fp32_onnx_stats['std_batch_ms']:.3f} ms")
print(f"  Median per batch: {fp32_onnx_stats['median_batch_ms']:.3f} ms")
print(f"  Mean per sample:  {fp32_onnx_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:       {1000.0 / fp32_onnx_stats['mean_sample_ms']:.1f} samples/sec")

#  Benchmark QONNX 
print("\n" + "="*70)
print("QONNX MODEL (QONNX Execution Context)")
print("="*70)
qonnx_stats = benchmark_qonnx_model(qonnx_model, test_loader, "QONNX")

print(f"\nResults ({qonnx_stats['num_batches']} batches, {qonnx_stats['total_samples']} samples):")
print(f"  Mean per batch:   {qonnx_stats['mean_batch_ms']:.3f} ± {qonnx_stats['std_batch_ms']:.3f} ms")
print(f"  Median per batch: {qonnx_stats['median_batch_ms']:.3f} ms")
print(f"  Mean per sample:  {qonnx_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:       {1000.0 / qonnx_stats['mean_sample_ms']:.1f} samples/sec")

#  Comparison 
print("\n" + "="*70)
print("ONNX RUNTIME COMPARISON: FP32 vs QONNX")
print("="*70)

speedup = fp32_onnx_stats['mean_sample_ms'] / qonnx_stats['mean_sample_ms']
if speedup > 1.0:
    print(f" QONNX is {speedup:.2f}x FASTER than FP32 ONNX")
elif speedup > 0.95:
    print(f"≈ QONNX and FP32 ONNX have similar speeds ({speedup:.2f}x)")
else:
    print(f" QONNX is {1/speedup:.2f}x SLOWER than FP32 ONNX")

print(f"\nPer-sample inference time:")
print(f"  FP32 ONNX: {fp32_onnx_stats['mean_sample_ms']:.4f} ms")
print(f"  QONNX:     {qonnx_stats['mean_sample_ms']:.4f} ms")
print(f"  Difference: {abs(fp32_onnx_stats['mean_sample_ms'] - qonnx_stats['mean_sample_ms']):.4f} ms")

print(f"\nThroughput (samples/sec):")
print(f"  FP32 ONNX: {1000.0 / fp32_onnx_stats['mean_sample_ms']:.1f}")
print(f"  QONNX:     {1000.0 / qonnx_stats['mean_sample_ms']:.1f}")

#  Model Size Comparison 
import os
print("\n" + "="*70)
print("MODEL SIZE COMPARISON")
print("="*70)
fp32_size_mb = os.path.getsize(fp32_onnx_path) / (1024*1024)
qonnx_size_mb = os.path.getsize(qonnx_path) / (1024*1024)
size_reduction = (1 - qonnx_size_mb / fp32_size_mb) * 100

print(f"FP32 ONNX: {fp32_size_mb:.2f} MB")
print(f"QONNX:     {qonnx_size_mb:.2f} MB")
print(f"Size reduction: {size_reduction:.1f}%")

#  Expected Results Note 
print("\n" + "="*70)
print("NOTE: Expected Behavior")
print("="*70)
print("""
On CPU with QONNX Execution Context:
  • QONNX is typically SLOWER than FP32 (Python-based execution overhead)
  • QONNX execution context is primarily for VERIFICATION, not performance
  • True speedup requires hardware deployment:
    → FPGA deployment (FINN framework - synthesizes to Verilog/VHDL)
    → ASIC designs (custom silicon)
    → The QONNX model is ready for FINN hardware build!

For CPU/GPU inference performance, use the standard ONNX export instead.
""")
print(f"Current execution: Python-based QONNX")
print("="*70)
# Out:
# ======================================================================
# INFERENCE SPEED COMPARISON: FP32 ONNX vs QONNX
# ======================================================================
#
# [1/2] Loading FP32 ONNX model (ONNX Runtime)...
# ✓ FP32 ONNX loaded with providers: ['CPUExecutionProvider']
#
# [2/2] Loading QONNX model (QONNX Execution Context)...
#   Inferring tensor shapes...
# ✓ QONNX model loaded successfully
#   Input name: x.7
#   Output name: 90
#
# Warming up both models...
# ✓ Warmup complete
#
# ======================================================================
# FP32 ONNX MODEL (ONNX Runtime)
# ======================================================================
# ✓ Warmup complete
#
# ======================================================================
# FP32 ONNX MODEL (ONNX Runtime)
# ======================================================================
# Benchmarking FP32 ONNX: 100%|██████████| 1563/1563 [00:22<00:00, 69.90it/s]
# Benchmarking FP32 ONNX: 100%|██████████| 1563/1563 [00:22<00:00, 69.90it/s]
# Results (1563 batches, 100000 samples):
#   Mean per batch:   5.469 ± 1.832 ms
#   Median per batch: 5.207 ms
#   Mean per sample:  0.0855 ms
#   Throughput:       11698.9 samples/sec
#
# ======================================================================
# QONNX MODEL (QONNX Execution Context)
# ======================================================================
# Benchmarking QONNX:   0%|          | 0/1563 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[65], line 148
#     146 print("QONNX MODEL (QONNX Execution Context)")
#     147 print("="*70)
# --> 148 qonnx_stats = benchmark_qonnx_model(qonnx_model, test_loader, "QONNX")
#     150 print(f"\nResults ({qonnx_stats['num_batches']} batches, {qonnx_stats['total_samples']} samples):")
#     151 print(f"  Mean per batch:   {qonnx_stats['mean_batch_ms']:.3f} ± {qonnx_stats['std_batch_ms']:.3f} ms")
#
# Cell In[65], line 113, in benchmark_qonnx_model(model, loader, model_name)
#     111 start = time.perf_counter()
#     112 input_dict = {input_name: images_np}
# --> 113 _ = execute_onnx(model, input_dict, return_full_exec_context=False)
#     114 end = time.perf_counter()
#     116 elapsed_ms = (end - start) * 1000
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/qonnx/core/onnx_exec.py:145, in execute_onnx(model, input_dict, return_full_exec_context, start_node, end_node)
#     143             execution_context[inp_name] = input_dict[inp_name]
#     144         else:
# --> 145             raise Exception(
#     146                 "Shape mismatch for provided input %s: found %s expected %s "
#     147                 % (
#     148                     inp_name,
#     149                     str(execution_context[inp_name].shape),
#     150                     str(input_dict[inp_name].shape),
#     151                 )
#     152             )
#     153     # else:
#     154     # raise Exception("Provided input not found in graph context: %s" % inp_name)
#     155
#     156 # check if model has an execution mode set
#     157 # if None, execute model node by node using execute_node()
#     158 model_exec_mode = model.get_metadata_prop("exec_mode")
#
# Exception: Shape mismatch for provided input x.7: found (1, 1, 20, 20) expected (64, 1, 20, 20)

# %% [markdown]
# ## Note: QONNX Batch Size Limitation
#
# **Issue**: The exported QONNX model has a **fixed batch size** in its input shape (e.g., `[64, 1, 20, 20]`). This is because the QONNX export captured the exact input shape used during export.
#
# **Solution**: For QONNX inference benchmarking, we need to either:
# 1. ✅ **Use a DataLoader with matching batch_size** (e.g., 64)
# 2. Process samples one at a time (batch_size=1)
# 3. Re-export QONNX with dynamic batch dimension
#
# The cell below creates a properly configured DataLoader for QONNX testing.

# %%
# FIXED: QONNX Inference with Proper Batch Size Handling

import onnxruntime as ort
import numpy as np
import time
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader

# Import QONNX
from qonnx.core.modelwrapper import ModelWrapper
from qonnx.core.onnx_exec import execute_onnx
from qonnx.transformation.infer_shapes import InferShapes

print("="*70)
print("INFERENCE SPEED COMPARISON: FP32 ONNX vs QONNX")
print("="*70)

# Paths
fp32_onnx_path = "exports/ellipse_fp32_model.onnx"
qonnx_path = "ellipse_regression_qonnx.onnx"

#  Load FP32 ONNX Model
print("\n[1/3] Loading FP32 ONNX model...")
sess_options = ort.SessionOptions()
sess_options.graph_optimization_level = ort.GraphOptimizationLevel.ORT_ENABLE_ALL
providers = ['CPUExecutionProvider']

fp32_session = ort.InferenceSession(fp32_onnx_path, sess_options, providers=providers)
print(f"✓ FP32 ONNX loaded")

#  Load QONNX Model
print("\n[2/3] Loading QONNX model...")
qonnx_model = ModelWrapper(qonnx_path)
qonnx_model = qonnx_model.transform(InferShapes())

# Get QONNX input shape to determine required batch size
input_tensor = qonnx_model.graph.input[0]
input_shape = [d.dim_value for d in input_tensor.type.tensor_type.shape.dim]
qonnx_batch_size = input_shape[0]

print(f"✓ QONNX model loaded")
print(f"  Input shape: {input_shape}")
print(f"  Required batch size: {qonnx_batch_size}")

#  Create DataLoader with Matching Batch Size
print(f"\n[3/3] Creating DataLoader with batch_size={qonnx_batch_size}...")

# Check if we need to recreate the loader
current_batch_size = test_loader.batch_size
if current_batch_size != qonnx_batch_size:
    print(f"  Current test_loader has batch_size={current_batch_size}")
    print(f"  Creating new loader with batch_size={qonnx_batch_size}")
    
    test_dataset = test_loader.dataset
    qonnx_test_loader = DataLoader(
        test_dataset,
        batch_size=qonnx_batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=False
    )
    print(f"✓ Created qonnx_test_loader with {len(qonnx_test_loader)} batches")
else:
    qonnx_test_loader = test_loader
    print(f"✓ Using existing test_loader")

#  Warmup
print("\nWarming up models...")
dummy_np = np.random.randn(*input_shape).astype(np.float32)

for _ in range(5):
    _ = fp32_session.run(None, {'input': dummy_np})

input_name = qonnx_model.graph.input[0].name
for _ in range(5):
    _ = execute_onnx(qonnx_model, {input_name: dummy_np}, return_full_exec_context=False)

print("✓ Warmup complete\n")

# Benchmark Functions
def benchmark_fp32(session, loader):
    times = []
    total_samples = 0
    
    for batch in tqdm(loader, desc="Benchmarking FP32"):
        images_np = batch["image"].numpy().astype(np.float32)
        batch_size = images_np.shape[0]
        
        start = time.perf_counter()
        _ = session.run(None, {'input': images_np})
        elapsed_ms = (time.perf_counter() - start) * 1000
        
        times.append(elapsed_ms)
        total_samples += batch_size
    
    times = np.array(times)
    avg_batch = total_samples / len(times)
    
    return {
        'mean_batch_ms': times.mean(),
        'std_batch_ms': times.std(),
        'mean_sample_ms': times.mean() / avg_batch,
        'total_samples': total_samples,
        'num_batches': len(times)
    }

def benchmark_qonnx(model, loader):
    input_name = model.graph.input[0].name
    times = []
    total_samples = 0
    
    for batch in tqdm(loader, desc="Benchmarking QONNX"):
        images_np = batch["image"].numpy().astype(np.float32)
        batch_size = images_np.shape[0]
        
        start = time.perf_counter()
        _ = execute_onnx(model, {input_name: images_np}, return_full_exec_context=False)
        elapsed_ms = (time.perf_counter() - start) * 1000
        
        times.append(elapsed_ms)
        total_samples += batch_size
    
    times = np.array(times)
    avg_batch = total_samples / len(times)
    
    return {
        'mean_batch_ms': times.mean(),
        'std_batch_ms': times.std(),
        'mean_sample_ms': times.mean() / avg_batch,
        'total_samples': total_samples,
        'num_batches': len(times)
    }

#  Run Benchmarks
print("="*70)
print("FP32 ONNX MODEL")
print("="*70)
fp32_stats = benchmark_fp32(fp32_session, qonnx_test_loader)

print(f"\nResults ({fp32_stats['num_batches']} batches, {fp32_stats['total_samples']} samples):")
print(f"  Mean per batch:   {fp32_stats['mean_batch_ms']:.3f} ± {fp32_stats['std_batch_ms']:.3f} ms")
print(f"  Mean per sample:  {fp32_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:       {1000.0 / fp32_stats['mean_sample_ms']:.1f} samples/sec")

print("\n" + "="*70)
print("QONNX MODEL")
print("="*70)
qonnx_stats = benchmark_qonnx(qonnx_model, qonnx_test_loader)

print(f"\nResults ({qonnx_stats['num_batches']} batches, {qonnx_stats['total_samples']} samples):")
print(f"  Mean per batch:   {qonnx_stats['mean_batch_ms']:.3f} ± {qonnx_stats['std_batch_ms']:.3f} ms")
print(f"  Mean per sample:  {qonnx_stats['mean_sample_ms']:.4f} ms")
print(f"  Throughput:       {1000.0 / qonnx_stats['mean_sample_ms']:.1f} samples/sec")

#  Comparison
print("\n" + "="*70)
print("COMPARISON")
print("="*70)

speedup = fp32_stats['mean_sample_ms'] / qonnx_stats['mean_sample_ms']
print(f"\nPer-sample inference time:")
print(f"  FP32:  {fp32_stats['mean_sample_ms']:.4f} ms")
print(f"  QONNX: {qonnx_stats['mean_sample_ms']:.4f} ms")

if speedup > 1.0:
    print(f"\n✓ QONNX is {speedup:.2f}x FASTER than FP32")
else:
    print(f"\n⚠ QONNX is {1/speedup:.2f}x SLOWER than FP32")
    print("  This is expected: QONNX execution is Python-based (for verification)")
    print("  Real speedup requires FPGA/ASIC deployment via FINN framework")

# Model Size
import os
fp32_size = os.path.getsize(fp32_onnx_path) / (1024*1024)
qonnx_size = os.path.getsize(qonnx_path) / (1024*1024)

print(f"\nModel Size:")
print(f"  FP32:  {fp32_size:.2f} MB")
print(f"  QONNX: {qonnx_size:.2f} MB")
print(f"  Reduction: {(1 - qonnx_size/fp32_size)*100:.1f}%")

print("\n" + "="*70)
# Out:
# ======================================================================
# INFERENCE SPEED COMPARISON: FP32 ONNX vs QONNX
# ======================================================================
#
# [1/3] Loading FP32 ONNX model...
# ✓ FP32 ONNX loaded
#
# [2/3] Loading QONNX model...
# ✓ QONNX model loaded
#   Input shape: [1, 1, 20, 20]
#   Required batch size: 1
#
# [3/3] Creating DataLoader with batch_size=1...
#   Current test_loader has batch_size=64
#   Creating new loader with batch_size=1
# ✓ Created qonnx_test_loader with 100000 batches
#
# Warming up models...
# ✓ Warmup complete
#
# ======================================================================
# FP32 ONNX MODEL
# ======================================================================
# Benchmarking FP32: 100%|██████████| 100000/100000 [01:51<00:00, 898.66it/s]
# Results (100000 batches, 100000 samples):
#   Mean per batch:   0.303 ± 0.108 ms
#   Mean per sample:  0.3027 ms
#   Throughput:       3304.0 samples/sec
#
# ======================================================================
# QONNX MODEL
# ======================================================================
# Benchmarking QONNX:   5%|▌         | 5241/100000 [04:29<1:21:10, 19.46it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 149
#     147 print("QONNX MODEL")
#     148 print("="*70)
# --> 149 qonnx_stats = benchmark_qonnx(qonnx_model, qonnx_test_loader)
#     151 print(f"\nResults ({qonnx_stats['num_batches']} batches, {qonnx_stats['total_samples']} samples):")
#     152 print(f"  Mean per batch:   {qonnx_stats['mean_batch_ms']:.3f} ± {qonnx_stats['std_batch_ms']:.3f} ms")
#
# Cell In[66], line 118, in benchmark_qonnx(model, loader)
#     115 batch_size = images_np.shape[0]
#     117 start = time.perf_counter()
# --> 118 _ = execute_onnx(model, {input_name: images_np}, return_full_exec_context=False)
#     119 elapsed_ms = (time.perf_counter() - start) * 1000
#     121 times.append(elapsed_ms)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/qonnx/core/onnx_exec.py:126, in execute_onnx(model, input_dict, return_full_exec_context, start_node, end_node)
#     124 if not model.check_all_tensor_shapes_specified():
#     125     raise Exception("Found unspecified tensor shapes, try infer_shapes")
# --> 126 ret = model.analysis(ta.nodes_topologically_sorted)
#     127 assert (
#     128     ret["nodes_topologically_sorted"] is True
#     129 ), """Nodes must be
#     130 topologically sorted."""
#     132 graph = model.graph
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/qonnx/core/modelwrapper.py:129, in ModelWrapper.analysis(self, analysis_fxn)
#     127 def analysis(self, analysis_fxn):
#     128     """Runs given anaylsis_fxn on this model and return resulting dict."""
# --> 129     return analysis_fxn(self)
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/qonnx/analysis/topology.py:103, in nodes_topologically_sorted(model)
#     100 for successor in successors:
#     101     # check the condition by checking the antithesis
#     102     index_n = model.get_node_index(n)
# --> 103     index_suc = model.get_node_index(successor)
#     104     if index_n > index_suc:
#     105         all_OK = False
#
# File ~/miniconda3/envs/ellipse-qat/lib/python3.11/site-packages/qonnx/core/modelwrapper.py:594, in ModelWrapper.get_node_index(self, node)
#     592         if n == node:
#     593             return n_ind
# --> 594         n_ind += 1
#     595 except ValueError:
#     596     return None
#
# KeyboardInterrupt:

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 100  # match FPGA

# reuse the same dataset your existing test_loader is using
test_dataset = test_loader.dataset

test_loader_100 = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=False
)

print("Old batch size:", test_loader.batch_size)
print("New batch size:", test_loader_100.batch_size)
# Out:
# Old batch size: 64
# New batch size: 100

# %%
# CPU ONNX Runtime benchmark (FP32 + QAT ONNX)

import time
import numpy as np
import onnxruntime as ort
from tqdm import tqdm

# Update paths if needed
fp32_onnx_path = "exports/ellipse_fp32_model.onnx"
qat_onnx_path  = "exports/ellipse_qat4_model.onnx"   # <-- change to your QAT ONNX path

BATCH_LIMIT = None   # set to an int (e.g., 200) to cap runtime while testing, or leave None
WARMUP_BATCHES = 10

def make_ort_session_cpu(path):
    so = ort.SessionOptions()
    so.graph_optimization_level = ort.GraphOptimizationLevel.ORT_ENABLE_ALL
    return ort.InferenceSession(path, sess_options=so, providers=["CPUExecutionProvider"])

def ort_benchmark_session(session, loader, warmup_batches=10, batch_limit=None, desc="ORT"):
    input_name = session.get_inputs()[0].name

    # Warmup
    it = iter(loader)
    for _ in range(warmup_batches):
        try:
            batch = next(it)
        except StopIteration:
            break
        x = batch["image"].detach().cpu().numpy().astype(np.float32, copy=False)
        _ = session.run(None, {input_name: x})

    # Timed
    total_samples = 0
    t0 = time.perf_counter()
    nb = 0

    for batch in tqdm(loader, desc=desc):
        x = batch["image"].detach().cpu().numpy().astype(np.float32, copy=False)
        bs = x.shape[0]
        _ = session.run(None, {input_name: x})
        total_samples += bs
        nb += 1
        if batch_limit is not None and nb >= batch_limit:
            break

    t1 = time.perf_counter()
    total_time = t1 - t0

    return {
        "provider": session.get_providers()[0],
        "num_batches": nb,
        "total_samples": total_samples,
        "total_time_s": total_time,
        "throughput_sps": total_samples / total_time if total_time > 0 else float("nan"),
        "mean_sample_ms": (total_time / total_samples) * 1000.0 if total_samples > 0 else float("nan"),
    }

print("ONNX Runtime providers available:", ort.get_available_providers())

# FP32 on CPU
cpu_fp32_sess = make_ort_session_cpu(fp32_onnx_path)
cpu_fp32_stats = ort_benchmark_session(cpu_fp32_sess, test_loader, WARMUP_BATCHES, BATCH_LIMIT, desc="CPU FP32 ORT")

# QAT on CPU
cpu_qat_sess = make_ort_session_cpu(qat_onnx_path)
cpu_qat_stats = ort_benchmark_session(cpu_qat_sess, test_loader, WARMUP_BATCHES, BATCH_LIMIT, desc="CPU QAT ORT")

print("\n=== CPU RESULTS ===")
for name, st in [("FP32", cpu_fp32_stats), ("QAT", cpu_qat_stats)]:
    print(f"{name:4s} [{st['provider']}]  throughput={st['throughput_sps']:.1f} samples/s, "
          f"latency={st['mean_sample_ms']:.4f} ms/sample, total={st['total_samples']} samples in {st['total_time_s']:.3f}s")
# Out:
# ONNX Runtime providers available: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# 2026-02-17 19:29:20.732336668 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.741045322 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.743693418 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.749153998 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.762149583 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.769296696 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.772346331 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.779766793 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.789534672 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.795759014 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   0%|          | 0/1563 [00:00<?, ?it/s]2026-02-17 19:29:20.948493057 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   0%|          | 1/1563 [00:00<03:48,  6.84it/s]2026-02-17 19:29:20.954566979 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.963099414 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.969105039 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.975524976 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.978857589 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.988341127 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:20.994001819 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.000297505 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.006194137 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.008897196 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.011610113 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.013670094 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.021423335 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.031155598 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.033540434 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.040854598 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.048246977 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.051746131 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   1%|          | 19/1563 [00:00<00:17, 89.80it/s]2026-02-17 19:29:21.061384587 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.069296386 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.079175702 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.081222468 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.087713478 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.094547307 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.096918947 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.108530002 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.110272820 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.112752573 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.129445721 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.135122482 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.141234345 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.144569162 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.149713191 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   2%|▏         | 35/1563 [00:00<00:12, 118.36it/s]2026-02-17 19:29:21.155096206 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.168069839 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.170213806 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.178221382 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.180291112 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.185973324 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.187941011 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.197013554 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.198976282 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.203942360 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.213944064 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.218672959 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.227639714 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.230787262 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.237202981 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.246149107 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.250206971 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.252931510 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   3%|▎         | 52/1563 [00:00<00:11, 136.85it/s]2026-02-17 19:29:21.259053883 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.264137900 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.267371608 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.276044996 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.279063202 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.284019561 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.289398188 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.293646687 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.299355760 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.301375755 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.306932753 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.312359160 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.314664907 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.324090898 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.327568621 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.333955066 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.335965464 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.340217029 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.343018541 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.348970116 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.353049771 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.355155796 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.360297872 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   5%|▍         | 75/1563 [00:00<00:09, 164.89it/s]2026-02-17 19:29:21.365835134 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.376796046 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.380644179 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.388038964 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.394260932 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.397310237 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.403318597 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.410736184 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.417436413 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.426859770 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.431340693 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.436783238 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.447581016 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.452149502 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.458345893 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.463353278 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.465547358 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   6%|▌         | 92/1563 [00:00<00:08, 165.20it/s]2026-02-17 19:29:21.468342328 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.473122618 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.477917266 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.485758022 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.493053932 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.499696986 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.502311599 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.507271746 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.512936065 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.519508927 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.521543140 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.526859980 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.533516288 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.544098795 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.546102360 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.550055819 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.562118145 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   7%|▋         | 110/1563 [00:00<00:08, 168.56it/s]2026-02-17 19:29:21.568024185 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.572095042 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.574387447 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.580245897 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.590798147 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.593534339 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.601315473 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.603971483 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.611577012 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.618347763 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.620556030 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.625446676 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.631166899 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.636894555 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.644629734 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.646922328 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.652080534 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.654733930 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.662713394 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.663874259 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.667071638 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:   8%|▊         | 131/1563 [00:00<00:07, 179.65it/s]2026-02-17 19:29:21.671063039 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.677714388 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.686709766 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.690356053 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.693244779 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.703253575 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.708035320 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.710022093 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.713593630 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.720558313 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.723985954 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.726682399 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.730965553 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.735946379 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.741340513 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.746261336 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.748393671 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.758542860 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.760870400 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.763580772 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.766110747 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:  10%|▉         | 152/1563 [00:00<00:07, 187.09it/s]2026-02-17 19:29:21.774211378 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.776787951 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.780531068 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.784961057 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.789918207 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.795382272 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.801186332 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.804008974 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.812218547 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.815246421 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.817529778 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.819712145 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.827839456 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.833725979 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.835956156 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.839293016 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.849101169 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.852297398 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.855289686 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.857292149 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.867541745 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.870493377 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.872938284 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.877605004 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:  11%|█         | 175/1563 [00:01<00:07, 197.95it/s]2026-02-17 19:29:21.882608522 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.890785814 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.893709724 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.896192564 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.902035064 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.904271554 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.911660256 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.913906464 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.921651641 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.923763649 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.927465369 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.931049700 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.933134396 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.935630730 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.940635379 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.944429351 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.952690460 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.958066843 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.962276330 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.964359604 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.970706515 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.976246913 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.982328719 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:  13%|█▎        | 198/1563 [00:01<00:06, 204.57it/s]2026-02-17 19:29:21.987856925 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.993837464 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:21.999458772 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.002475325 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.007641756 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.013713784 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.016924880 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.024725972 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.029431945 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.035004572 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.040136990 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.043027118 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.048808875 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.059107402 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.064320711 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.068458564 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.070011519 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.077727302 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.084490268 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.086663088 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.091260979 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:  14%|█▍        | 219/1563 [00:01<00:06, 200.92it/s]2026-02-17 19:29:22.101118806 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.106265400 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.108488212 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.113488033 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.123287611 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.127741994 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.133071919 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.135486259 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.144398833 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.146774702 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.149178874 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.154781948 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.160571450 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.166256839 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.170102407 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.174874283 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.183990527 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.189987966 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.193119653 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.195054311 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.206817979 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU FP32 ORT:  15%|█▌        | 240/1563 [00:01<00:06, 194.60it/s]2026-02-17 19:29:22.212256998 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.214429978 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.217148716 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.225663428 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.230639745 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.233321886 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.238463980 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.243988108 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.246680015 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.254651896 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:22.259635095 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# ...
# 2026-02-17 19:29:51.352129849 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.369429044 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.403545907 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.422263416 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.432448612 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  95%|█████████▌| 1485/1563 [00:20<00:01, 71.86it/s]2026-02-17 19:29:51.442234021 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.452071749 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.469383387 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.491238434 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.508264109 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.522917133 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.538472488 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.545638014 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  96%|█████████▌| 1493/1563 [00:20<00:00, 71.56it/s]2026-02-17 19:29:51.552999376 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.564313745 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.578641332 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.589087824 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.600720085 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.611407376 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.628863024 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.639197196 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.661211501 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  96%|█████████▌| 1502/1563 [00:20<00:00, 73.35it/s]2026-02-17 19:29:51.676871761 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.698848435 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.713348363 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.725943630 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.739580599 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.756107666 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.763827756 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.776471764 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  97%|█████████▋| 1510/1563 [00:20<00:00, 72.23it/s]2026-02-17 19:29:51.793705267 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.809723855 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.822310736 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.830309446 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.843254105 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.860869529 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.872789177 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.886470880 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  97%|█████████▋| 1518/1563 [00:21<00:00, 72.33it/s]2026-02-17 19:29:51.899097766 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.916797809 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.926189835 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.934296346 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.944615830 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.961519038 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.972334738 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.984725674 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:51.993490081 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  98%|█████████▊| 1527/1563 [00:21<00:00, 75.68it/s]2026-02-17 19:29:52.008465616 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.018835515 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.034877046 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.049396030 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.068880607 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.085004603 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.098811749 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.115867700 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  98%|█████████▊| 1535/1563 [00:21<00:00, 72.36it/s]2026-02-17 19:29:52.133179188 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.140303859 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.154762559 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.178250029 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.194771936 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.202759255 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.217924672 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  99%|█████████▊| 1543/1563 [00:21<00:00, 71.50it/s]2026-02-17 19:29:52.231491841 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.247469333 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.255618252 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.277489139 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.297696546 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.313476088 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.322387368 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.338810861 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.355174473 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT:  99%|█████████▉| 1551/1563 [00:21<00:00, 69.29it/s]2026-02-17 19:29:52.384531543 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.400173480 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.426801995 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.440588793 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.448494810 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.461661242 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.470216297 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# CPU QAT ORT: 100%|█████████▉| 1558/1563 [00:21<00:00, 66.87it/s]2026-02-17 19:29:52.481437745 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.491963865 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.501616197 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.512936939 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:29:52.521438034 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {32,5} for output output
# CPU QAT ORT: 100%|██████████| 1563/1563 [00:21<00:00, 71.92it/s]
# === CPU RESULTS ===
# FP32 [CPUExecutionProvider]  throughput=10297.0 samples/s, latency=0.0971 ms/sample, total=100000 samples in 9.712s
# QAT  [CPUExecutionProvider]  throughput=4600.0 samples/s, latency=0.2174 ms/sample, total=100000 samples in 21.739s

# %%
import onnxruntime as ort

print("ONNX Runtime version:", ort.__version__)
print("Available providers:", ort.get_available_providers())

# Check if CUDA is available
if "CUDAExecutionProvider" in ort.get_available_providers():
    print("✅ GPU support is available!")
else:
    print("⚠️ GPU support NOT available - check CUDA/cuDNN installation")
# Out:
# ONNX Runtime version: 1.19.0
# Available providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# ✅ GPU support is available!

# %%
import onnxruntime as ort

print("ONNX Runtime version:", ort.__version__)
print("Available providers:", ort.get_available_providers())

# Check if CUDA is available
if "CUDAExecutionProvider" in ort.get_available_providers():
    print("✅ GPU support is available!")
else:
    print("⚠️ GPU support NOT available - check CUDA/cuDNN installation")
# Out:
# ONNX Runtime version: 1.19.0
# Available providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# ✅ GPU support is available!

# %%
# Check NVIDIA driver
# !nvidia-smi

# Check CUDA version
# !nvcc --version

# Check if CUDA libraries are in the path
# !echo $LD_LIBRARY_PATH
# Out:
# Tue Feb 17 19:30:31 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.288.01             Driver Version: 535.288.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off | 00000000:00:10.0 Off |                  Off |
# |  0%   43C    P8              20W / 450W |    573MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce RTX 4090        Off | 00000000:00:11.0 Off |                  Off |
# |  0%   37C    P8              18W / 450W |     14MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2859      G   /usr/lib/xorg/Xorg                            4MiB |
# |    0   N/A  N/A     10956      C   ...iconda3/envs/ellipse-qat/bin/python      556MiB |
# |    1   N/A  N/A      2859      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+
# /bin/bash: line 1: nvcc: command not found

# %%
# Cell: Verify ONNX Runtime GPU Support

import onnxruntime as ort

print("=" * 60)
print("ONNX RUNTIME GPU CHECK")
print("=" * 60)
print(f"ONNX Runtime version: {ort.__version__}")
print(f"Available providers: {ort.get_available_providers()}")

if "CUDAExecutionProvider" in ort.get_available_providers():
    print("\n✅ GPU support is AVAILABLE!")
    print("\nTesting GPU session creation...")
    
    try:
        # Test creating a GPU session with your FP32 model
        session = ort.InferenceSession(
            "exports/ellipse_fp32_model.onnx",
            providers=['CUDAExecutionProvider', 'CPUExecutionProvider']
        )
        print(f"✅ GPU session created successfully!")
        print(f"   Active provider: {session.get_providers()[0]}")
        
        # Quick inference test
        import numpy as np
        dummy = np.random.randn(1, 1, 20, 20).astype(np.float32)
        output = session.run(None, {'input': dummy})
        print(f"✅ GPU inference test passed! Output shape: {output[0].shape}")
        
    except Exception as e:
        print(f"❌ GPU session failed: {e}")
else:
    print("\n⚠️ GPU support NOT available")
    print("\nTroubleshooting:")
    print("  1. Check CUDA installation: conda list | grep cuda")
    print("  2. Reinstall: pip install onnxruntime-gpu==1.19.0")
    print("  3. Ensure cuDNN is installed: conda install -c conda-forge cudnn")
# Out:
# ============================================================
# ONNX RUNTIME GPU CHECK
# ============================================================
# ONNX Runtime version: 1.19.0
# Available providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
#
# ✅ GPU support is AVAILABLE!
#
# Testing GPU session creation...
# ✅ GPU session created successfully!
#    Active provider: CUDAExecutionProvider
# ✅ GPU inference test passed! Output shape: (1, 5)

# %%
# GPU ONNX Runtime benchmark (FP32 + QAT ONNX)

import time
import numpy as np
import onnxruntime as ort
from tqdm import tqdm

# Update paths if needed
fp32_onnx_path = "exports/ellipse_fp32_model.onnx"
qat_onnx_path  = "exports/ellipse_qat4_model.onnx"   # <-- change to your QAT ONNX path

BATCH_LIMIT = None
WARMUP_BATCHES = 10

def make_ort_session_gpu(path):
    so = ort.SessionOptions()
    so.graph_optimization_level = ort.GraphOptimizationLevel.ORT_ENABLE_ALL

    # Try CUDA (GPU). If CUDA is not installed, this will fail.
    return ort.InferenceSession(path, sess_options=so, providers=["CUDAExecutionProvider"])

def ort_benchmark_session(session, loader, warmup_batches=10, batch_limit=None, desc="ORT"):
    input_name = session.get_inputs()[0].name

    # Warmup
    it = iter(loader)
    for _ in range(warmup_batches):
        try:
            batch = next(it)
        except StopIteration:
            break
        x = batch["image"].detach().cpu().numpy().astype(np.float32, copy=False)
        _ = session.run(None, {input_name: x})

    # Timed
    total_samples = 0
    t0 = time.perf_counter()
    nb = 0

    for batch in tqdm(loader, desc=desc):
        x = batch["image"].detach().cpu().numpy().astype(np.float32, copy=False)
        bs = x.shape[0]
        _ = session.run(None, {input_name: x})
        total_samples += bs
        nb += 1
        if batch_limit is not None and nb >= batch_limit:
            break

    t1 = time.perf_counter()
    total_time = t1 - t0

    return {
        "provider": session.get_providers()[0],
        "num_batches": nb,
        "total_samples": total_samples,
        "total_time_s": total_time,
        "throughput_sps": total_samples / total_time if total_time > 0 else float("nan"),
        "mean_sample_ms": (total_time / total_samples) * 1000.0 if total_samples > 0 else float("nan"),
    }

print("ONNX Runtime providers available:", ort.get_available_providers())
if "CUDAExecutionProvider" not in ort.get_available_providers():
    raise RuntimeError(
        "CUDAExecutionProvider is not available. Install onnxruntime-gpu and ensure CUDA/cuDNN are configured."
    )

# FP32 on GPU
gpu_fp32_sess = make_ort_session_gpu(fp32_onnx_path)
gpu_fp32_stats = ort_benchmark_session(gpu_fp32_sess, test_loader, WARMUP_BATCHES, BATCH_LIMIT, desc="GPU FP32 ORT")

# QAT on GPU
gpu_qat_sess = make_ort_session_gpu(qat_onnx_path)
gpu_qat_stats = ort_benchmark_session(gpu_qat_sess, test_loader, WARMUP_BATCHES, BATCH_LIMIT, desc="GPU QAT ORT")

print("\n=== GPU RESULTS ===")
for name, st in [("FP32", gpu_fp32_stats), ("QAT", gpu_qat_stats)]:
    print(f"{name:4s} [{st['provider']}]  throughput={st['throughput_sps']:.1f} samples/s, "
          f"latency={st['mean_sample_ms']:.4f} ms/sample, total={st['total_samples']} samples in {st['total_time_s']:.3f}s")
# Out:
# ONNX Runtime providers available: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# 2026-02-17 19:30:41.580492698 [W:onnxruntime:, session_state.cc:1166 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2026-02-17 19:30:41.580507384 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# 2026-02-17 19:30:41.743088592 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.744336248 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.744686401 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.745014813 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.745369404 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.745627415 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.745988758 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.746306289 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.746576524 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.755501127 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:   0%|          | 0/1563 [00:00<?, ?it/s]2026-02-17 19:30:41.894862619 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:   0%|          | 1/1563 [00:00<03:34,  7.28it/s]2026-02-17 19:30:41.896604445 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.897096412 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.897443590 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.901609903 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.901891548 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.902163335 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.902457794 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.908394009 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.908751114 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.909723317 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.910038594 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.916205056 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.916599672 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.917865140 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.918159199 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.922547206 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.922855502 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.924748289 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.925102069 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.930054619 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.930403820 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.932496069 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.932902197 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.936912410 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.937220515 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.940026174 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.940359906 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.943868134 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.944168054 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.947716076 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.948106254 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.950948170 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.951233483 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.955278130 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.955694096 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.959240666 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.959693880 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.963232035 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.963584482 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.966475250 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.966730776 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.971061568 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.971388116 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.975193839 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.975523264 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.979132962 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.979434974 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.982734975 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.983017201 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.986559112 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.986867898 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.991403512 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.991992129 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.994440452 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.994992981 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:41.997594549 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:   4%|▎         | 57/1563 [00:00<00:05, 285.37it/s]2026-02-17 19:30:41.998666197 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.002427819 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.002979847 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.005829588 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.006318069 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.009172048 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.009722063 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.012264762 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.013655053 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.016851170 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.017206202 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.019681806 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.021176712 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.023772981 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.024384341 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.027620201 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.029945415 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.031087114 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.031465087 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.035534322 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.039635035 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.040065797 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.040420258 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.043922325 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.047832553 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.048454132 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.048978660 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.051383952 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.056169031 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.056775080 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.057281855 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.061096584 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.064430398 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.064777035 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.065161471 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.069103998 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.070945181 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.071264866 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.071557392 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.076247712 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.077893200 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.078189321 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.078531199 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.083575100 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.085279918 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.086296823 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.086688011 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.090000015 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.091975536 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.092948510 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.093282341 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.097574723 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.099138006 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:   7%|▋         | 110/1563 [00:00<00:03, 385.22it/s]2026-02-17 19:30:42.100469037 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.100873921 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.104720601 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.105899748 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.106871089 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.107223676 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.112635473 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.113651035 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.114598912 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.114922625 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.121309630 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.121630828 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.123183802 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.123574090 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.127598671 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.127900273 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.131750739 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.132053935 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.134612303 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.134954781 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.140272623 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.140569275 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.142961774 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.143348556 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.148306205 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.148663862 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.150265457 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.150550739 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.154815858 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.155198992 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.157939329 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.158586606 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.166229290 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.166919506 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.169215636 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.169722811 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.174066106 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.174683206 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.177903469 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.178301640 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.180867462 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.181216343 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.187719093 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.188133024 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.188841835 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.189225811 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.195473485 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.195920499 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.196351482 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.196978261 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.203365655 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:  10%|█         | 161/1563 [00:00<00:03, 424.74it/s]2026-02-17 19:30:42.204469773 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.204893493 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.205370822 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.210891031 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.211406441 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.211803831 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.212328619 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.219415208 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.219829820 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.220227232 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.220620023 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.228181206 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.228556535 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.228942584 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.229358900 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.234553752 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.234972984 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.235313750 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.235673590 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.242673947 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.243037494 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.243430898 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.243765823 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.249710531 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.250189023 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.250449800 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.250740211 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.257496042 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.257972591 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.258432919 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.258808268 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.264907756 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.265299386 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.265617258 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.265960408 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.271944200 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.272258287 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.272565419 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.272938604 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.279544686 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.280243859 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.280684591 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.281135982 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.286514236 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.286918420 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.287325458 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.287795595 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.294300989 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.294752331 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.295116479 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.295554306 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.301456406 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.301979531 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.302390366 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.302831639 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.310560254 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU FP32 ORT:  14%|█▍        | 217/1563 [00:00<00:02, 460.06it/s]2026-02-17 19:30:42.311698976 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.312227742 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.312589546 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.317917285 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.318337668 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.318737935 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.319063030 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.324620288 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.325006147 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.325377109 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.325777084 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.331768772 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.332223709 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.332682956 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.333197013 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.339468112 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.339858539 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.340349664 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.340748798 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.347313674 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.347934141 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.348531534 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.349137623 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.355989533 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.356670253 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.357908281 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.358529288 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.364822897 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.365432714 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.365993619 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.366366665 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.373722364 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.374426116 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:42.374936628 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# ...
# 2026-02-17 19:30:48.438700164 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.439140134 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.439610240 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.439990880 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.443815748 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.444333964 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.445764029 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.446177410 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.450739122 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.451331667 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.451799017 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.452617312 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.456901197 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.457337159 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.458087508 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.458926881 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.463014671 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.463441516 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.464910153 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.466093810 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.469630030 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.470059631 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.471034669 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.472600266 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.475977982 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.476401671 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.477778968 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.479796719 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.482653583 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.483035274 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.484490307 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.486232153 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.489059001 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.489549495 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.491771517 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.493967269 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.496008704 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.496424028 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.498329049 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.501558638 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.502637319 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.503032875 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.509322558 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.510737325 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.512384926 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.513149280 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.514505288 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.518306723 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.518823275 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.519299682 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.520745959 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.524611623 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.525112367 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.525595978 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.526628122 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.531209079 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.531615408 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.532004121 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.533268798 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.537771951 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# GPU QAT ORT:  98%|█████████▊| 1537/1563 [00:03<00:00, 544.62it/s]2026-02-17 19:30:48.538837336 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.539450791 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.540359123 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.544458253 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.544864049 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.545268683 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.546874657 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.549916546 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.550945194 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.551347423 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.553301975 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.556739181 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.557962632 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.558382665 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.560184162 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.565866142 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.568692329 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.569208301 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.570459223 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.573920083 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.574448519 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.574821964 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.575173440 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.578352044 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.578679714 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {64,5} for output output
# 2026-02-17 19:30:48.587284882 [W:onnxruntime:, execution_frame.cc:870 VerifyOutputSizes] Expected shape from model of {1,5} does not match actual shape of {32,5} for output output
# GPU QAT ORT: 100%|██████████| 1563/1563 [00:03<00:00, 493.05it/s]
# === GPU RESULTS ===
# FP32 [CUDAExecutionProvider]  throughput=31761.5 samples/s, latency=0.0315 ms/sample, total=100000 samples in 3.148s
# QAT  [CUDAExecutionProvider]  throughput=31528.1 samples/s, latency=0.0317 ms/sample, total=100000 samples in 3.172s

# %%
# Cell: Launch Netron Visualizer

import netron
import os

qonnx_path = "ellipse_regression_qonnx.onnx"
#qonnx_path = "exports/ellipse_qat_model.onnx"

if os.path.exists(qonnx_path):
    print(f" Launching Netron for: {qonnx_path}")
    netron.start(qonnx_path)
else:
    print(f" File not found: {qonnx_path}")
    print("   Run the QONNX export cell first!")
# Out:
# Serving 'ellipse_regression_qonnx.onnx' at http://localhost:8080
#  Launching Netron for: ellipse_regression_qonnx.onnx
